# %%
import torch
from torch import nn
from torch.nn import functional as F
import multiprocessing
# utility functions
import json
import os
from ipynb.fs.full.utilities import BERTModel, download_extract, Vocab, load_data_snli, try_all_gpus, TokenEmbedding, train_and_evaluate, get_dataloader_workers, SNLIBERTDataset, read_snli, BERTClassifier, display_results, unit_testing, compare_results

# %%
# global variables
devices = try_all_gpus()
# Out:
#  ---> will run on mps gpu(s) count 1

# %% [markdown]
# #### Natural Language Inference with `Decomposable attention model with MLPs(Multi Layer Perceptrons) and GloVe embeddings`
# ![Solution Overview](images/NaturalLanguageInference.GloVe.png)
# ###### The solution will feed pretrained [GloVe](GLOVE.md) embeddings to [MLP](MLP.md) and [Attention](ATTENTION.md)

# %%
def mlp(num_inputs, num_hiddens, flatten):
    """Inputs are separately taken rather than takes a pair of them together.
       This decomposition trick leads to only m+n applications (linear complexity) 
       rather than m*n applications (quadratic complexity).
    """
    net = []
    net.append(nn.Dropout(0.2))
    net.append(nn.Linear(num_inputs, num_hiddens))
    net.append(nn.ReLU())
    if flatten:
        net.append(nn.Flatten(start_dim=1))
    net.append(nn.Dropout(0.2))
    net.append(nn.Linear(num_hiddens, num_hiddens))
    net.append(nn.ReLU())
    if flatten:
        net.append(nn.Flatten(start_dim=1))
    return nn.Sequential(*net)

# %%
class Attend(nn.Module):
    """Compute the soft alignment of hypotheses (beta) withinput premises A and 
       soft alignment of premises (alpha) with input hypotheses B.
    """
    def __init__(self, num_inputs, num_hiddens, **kwargs):
        super(Attend, self).__init__(**kwargs)
        self.f = mlp(num_inputs, num_hiddens, flatten=False)
    def forward(self, A, B):
        # Shape of `A`/`B`: (`batch_size`, no. of tokens in sequence A/B,
        # `embed_size`)
        # Shape of `f_A`/`f_B`: (`batch_size`, no. of tokens in sequence A/B,
        # `num_hiddens`)
        f_A = self.f(A)
        f_B = self.f(B)
        # Shape of `e`: (`batch_size`, no. of tokens in sequence A,
        # no. of tokens in sequence B)
        e = torch.bmm(f_A, f_B.permute(0, 2, 1))
        # Shape of `beta`: (`batch_size`, no. of tokens in sequence A,
        # `embed_size`), where sequence B is softly aligned with each token
        # (axis 1 of `beta`) in sequence A
        beta = torch.bmm(F.softmax(e, dim=-1), B)
        # Shape of `alpha`: (`batch_size`, no. of tokens in sequence B,
        # `embed_size`), where sequence A is softly aligned with each token
        # (axis 1 of `alpha`) in sequence B
        alpha = torch.bmm(F.softmax(e.permute(0, 2, 1), dim=-1), A)
        return beta, alpha

# %%
class Compare(nn.Module):
    """Compare between token 𝑖 in the premise and all the hypothesis tokens that are softly aligned with token 𝑖 and 
       compare between token 𝑗 in the hypothesis and all the premise tokens that are softly aligned with token 𝑗.
    """
    def __init__(self, num_inputs, num_hiddens, **kwargs):
        super(Compare, self).__init__(**kwargs)
        self.g = mlp(num_inputs, num_hiddens, flatten=False)
    def forward(self, A, B, beta, alpha):
        V_A = self.g(torch.cat([A, beta], dim=2))
        V_B = self.g(torch.cat([B, alpha], dim=2))
        return V_A, V_B

# %%
class Aggregate(nn.Module):
    """With two comparision vectors as input, aggregate that information to infer the logical relationship.
       This involes summing up both vectors and feed the concatenation of both summarization results into 
       function ℎ (an MLP) to obtain the classification result of the logical relationship.
    """
    def __init__(self, num_inputs, num_hiddens, num_outputs, **kwargs):
        super(Aggregate, self).__init__(**kwargs)
        self.h = mlp(num_inputs, num_hiddens, flatten=True)
        self.linear = nn.Linear(num_hiddens, num_outputs)
    def forward(self, V_A, V_B):
        # Sum up both sets of comparison vectors
        V_A = V_A.sum(dim=1)
        V_B = V_B.sum(dim=1)
        # Feed the concatenation of both summarization results into an MLP
        Y_hat = self.linear(self.h(torch.cat([V_A, V_B], dim=1)))
        return Y_hat

# %%
class DecomposableAttention(nn.Module):
    """Model to jointly train attention, comparing and aggregating steps together."""
    def __init__(self, vocab, embed_size, num_hiddens, num_inputs_attend=100, num_inputs_compare=200, num_inputs_agg=400, **kwargs):
        super(DecomposableAttention, self).__init__(**kwargs)
        self.embedding = nn.Embedding(len(vocab), embed_size)
        self.attend = Attend(num_inputs_attend, num_hiddens)
        self.compare = Compare(num_inputs_compare, num_hiddens)
        # There are 3 possible outputs: entailment, contradiction, and neutral
        self.aggregate = Aggregate(num_inputs_agg, num_hiddens, num_outputs=3)
    def forward(self, X):
        premises, hypotheses = X
        A = self.embedding(premises)
        B = self.embedding(hypotheses)
        beta, alpha = self.attend(A, B)
        V_A, V_B = self.compare(A, B, beta, alpha)
        Y_hat = self.aggregate(V_A, V_B)
        return Y_hat

# %%
# Reading the dataset
batch_size, num_steps = 256, 50
train_iter, test_iter, glove_vocab, data_dir = load_data_snli(batch_size, num_steps)
# Out:
#  ---> snli data already extracted at ../data/snli_1.0
#  ---> read 549367 examples
#  ---> read 9824 examples

# %%
# create Model
embed_size, num_hiddens = 100, 200
glove_net = DecomposableAttention(glove_vocab, embed_size, num_hiddens)
glove_embedding = TokenEmbedding('glove.6b.100d')
embeds = glove_embedding[glove_vocab.idx_to_token]
glove_net.embedding.weight.data.copy_(embeds)
# Out:
# tensor([[ 0.3847,  0.4935,  0.4910,  ...,  0.0263,  0.3905,  0.5222],
#         [-0.6610, -0.0730,  0.9238,  ..., -0.2256,  0.8148, -0.4405],
#         [ 0.9747,  1.2276,  0.4538,  ...,  0.2209,  1.7439, -0.8991],
#         ...,
#         [-0.0205, -0.4512,  0.6993,  ...,  0.0381,  0.2786,  0.2889],
#         [-0.2484, -0.2568,  0.0255,  ...,  0.2161, -0.3413,  0.6266],
#         [-0.1438,  0.8681, -0.7219,  ...,  0.0553, -0.4339,  0.3486]])

# %%
# training and evaluating the model
lr, num_epochs = 0.001, 4
trainer = torch.optim.Adam(glove_net.parameters(), lr=lr)
loss = nn.CrossEntropyLoss(reduction="none")
glove_results = train_and_evaluate(glove_net, train_iter, test_iter, loss, trainer, num_epochs, devices)
# Out:
# {'training': {'total_examples': 549367.0, 'passed': 442380.0, 'failed': 106987.0, 'accuracy': 80, 'loss': '0.496'}, 'test': {'total_examples': 9824.0, 'passed': 8115.0, 'failed': 1709.0, 'accuracy': 82, 'loss': '0.174'}}

# %%
display_results(glove_results, "glove_embedding_results")

# %% [markdown]
# #### Natural Language Inference with `MLP(Multi Layer Perceptrons) and BERT(Bidirectional Encoder Representations from Transformers) embeddings`
# ![Solution Overview](images/NaturalLanguageInference.BERT.png)
# ###### The solution will feed pretrained [BERT](BERT.md) embeddings to [MLP](MLP.md)

# %%
# # bert.small --> for development
bert_type ="bert.small"
num_hiddens = 256
ffn_num_hiddens = 512
num_heads = 4
num_blks = 2

# %%
def load_pretrained_model(pretrained_model, num_hiddens, ffn_num_hiddens, num_heads, num_blks, dropout, max_len, devices):
    data_dir = download_extract(pretrained_model)
    # Define an empty vocabulary to load the predefined vocabulary
    vocab = Vocab()
    vocab.idx_to_token = json.load(open(os.path.join(data_dir, 'vocab.json')))
    vocab.token_to_idx = {token: idx for idx, token in enumerate(
    vocab.idx_to_token)}
    bert = BERTModel(len(vocab), num_hiddens, ffn_num_hiddens=ffn_num_hiddens, num_heads=num_heads,num_blks=num_blks, dropout=dropout, max_len=max_len)
    # Load pretrained BERT parameters
    bert.load_state_dict(torch.load(os.path.join(data_dir, 'pretrained.params')))
    return bert, vocab

# %%
# load pretrained BERT 
bert_small_model, bert_small_vocab = load_pretrained_model(bert_type, num_hiddens=num_hiddens, ffn_num_hiddens=ffn_num_hiddens, num_heads=num_heads, num_blks=num_blks, dropout=0.1, max_len=512, devices=devices)

# %%
# Dataset for fine tuning BERT
# Reduce `batch_size` if there is an out of memory error. In the original BERT model, `max_len` = 512
batch_size, max_len, num_workers = 512, 128, get_dataloader_workers()
train_set = SNLIBERTDataset(read_snli(data_dir, True), max_len, bert_small_vocab)
test_set = SNLIBERTDataset(read_snli(data_dir, False), max_len, bert_small_vocab)
train_iter = torch.utils.data.DataLoader(train_set, batch_size, shuffle=True, num_workers=num_workers)
test_iter = torch.utils.data.DataLoader(test_set, batch_size, num_workers=num_workers)
# Out:
#  ---> read 549367 examples
#  ---> read 9824 examples

# %%
# Fine tuning BERT
bert_small_net = BERTClassifier(bert_small_model)

# %%
# train and evaluate Model performance
lr, num_epochs = 1e-4, 5
trainer = torch.optim.Adam(bert_small_net.parameters(), lr=lr)
loss = nn.CrossEntropyLoss(reduction='none')
bert_small_net(next(iter(train_iter))[0])
bert_small_results = train_and_evaluate(bert_small_net, train_iter, test_iter, loss, trainer, num_epochs, devices)
# Out:
# {'training': {'total_examples': 549367.0, 'passed': 445076.0, 'failed': 104291.0, 'accuracy': 81, 'loss': '0.478'}, 'test': {'total_examples': 9824.0, 'passed': 7709.0, 'failed': 2115.0, 'accuracy': 78, 'loss': '0.215'}}

# %%
# display results
display_results(bert_small_results, f'{bert_type}_embedding_results')

# %%
# # bert.base --> for evaluation and verification *** takes time ***
bert_type ="bert.base"
num_hiddens = 768
ffn_num_hiddens = 3072
num_heads = 12
num_blks = 12

# %%
# load pretrained BERT 
bert_base_model, bert_base_vocab = load_pretrained_model(bert_type, num_hiddens=num_hiddens, ffn_num_hiddens=ffn_num_hiddens, num_heads=num_heads, num_blks=num_blks, dropout=0.1, max_len=512, devices=devices)

# %%
# Dataset for fine tuning BERT
# Reduce `batch_size` if there is an out of memory error. In the original BERT model, `max_len` = 512
batch_size, max_len, num_workers = 512, 128, get_dataloader_workers()
train_set = SNLIBERTDataset(read_snli(data_dir, True), max_len, bert_base_vocab)
test_set = SNLIBERTDataset(read_snli(data_dir, False), max_len, bert_base_vocab)
train_iter = torch.utils.data.DataLoader(train_set, batch_size, shuffle=True, num_workers=num_workers)
test_iter = torch.utils.data.DataLoader(test_set, batch_size, num_workers=num_workers)
# Out:
#  ---> read 549367 examples
#  ---> read 9824 examples

# %%
# Fine tuning BERT
bert_base_net = BERTClassifier(bert_base_model)

# %%
# *** Risky *** , system may be get crashed, but needed to run for bert.base embeddings
# if bert_type == 'bert.base':
#     if devices[0].type == "cuda":
#         torch.cuda.set_per_process_memory_fraction(0.0)
#     elif devices[0].type == "mps":
#         torch.mps.set_per_process_memory_fraction(0.0)

# %%
# train and evaluate Model performance
lr, num_epochs = 1e-4, 5
trainer = torch.optim.Adam(bert_base_net.parameters(), lr=lr)
loss = nn.CrossEntropyLoss(reduction='none')
bert_base_net(next(iter(train_iter))[0])
# got the results running in in Colab.google.com with A100 GPU for 3 hrs.
bert_base_results =  {'training': {'total_examples': 549367.0, 'passed': 508342.0, 'failed': 41025.0, 'accuracy': 92, 'loss': '0.209'}, 'test': {'total_examples': 9824.0, 'passed': 8564.0, 'failed': 1260.0, 'accuracy': 87, 'loss': '0.128'}}
# bert_base_results = train_and_evaluate(bert_base_net, train_iter, test_iter, loss, trainer, num_epochs, devices)

# %% [markdown]
# ![Bert.Base training](images/bert.base.train.jpeg)

# %%
# display results
display_results(bert_base_results, f'{bert_type}_embedding_results')

# %%
# compare test results across glove embeddings, Bert base and Bert small
compare_results(glove_results, bert_base_results, bert_small_results)

# %%
# compare training results across glove embeddings, Bert base and Bert small
compare_results(glove_results, bert_base_results, bert_small_results, "training")

# %%
# unit testing
unit_testing(glove_net, glove_vocab, bert_small_net, bert_small_vocab, bert_base_net, bert_base_vocab)
# Out:
#  ---> will run on mps gpu(s) count 1
#  ---> will run on mps gpu(s) count 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 # unit testing
# ----> 2 unit_testing(glove_net, glove_vocab, bert_small_net, bert_small_vocab, bert_base_net, bert_base_vocab)
#
# File ~/Desktop/AI/Berkeley/projects/Capstone--Final-Report/utilities.ipynb:1057, in unit_testing(glove_net, glove_vocab, bert_small_net, bert_small_vocab, bert_base_net, bert_base_vocab)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "cbbcb80c-b34e-4df5-a5a2-678261bd2600",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "DATA_HUB = dict()\n",
#      11     "DATA_URL = 'http://d2l-data.s3-accelerate.amazonaws.com/'\n",
#      12     "DATA_HUB['SNLI'] = ('https://nlp.stanford.edu/projects/snli/snli_1.0.zip', '9fcde07509c7e87ec61c640c1b2753d9041758e4')\n",
#      13     "DATA_HUB['glove.6b.50d'] = (DATA_URL + 'glove.6B.50d.zip', '0b8703943ccdb6eb788e6f091b8946e82231bc4d')\n",
#      14     "DATA_HUB['glove.6b.100d'] = (DATA_URL + 'glove.6B.100d.zip', 'cd43bfb07e44e6f27cbcc7bc9ae3d80284fdaf5a')\n",
#      15     "DATA_HUB['glove.42b.300d'] = (DATA_URL + 'glove.42B.300d.zip', 'b5116e234e9eb9076672cfeabf5469f3eec904fa')\n",
#      16     "DATA_HUB['bert.small'] = (DATA_URL + 'bert.small.torch.zip', 'c72329e68a732bef0452e4b96a1c341c8910f81f')\n",
#      17     "DATA_HUB['bert.base'] = (DATA_URL + 'bert.base.torch.zip', '225d66f04cae318b841a13d32af3acc165f253ac')\n",
#      18     "\n",
#      19     "import numpy as np\n",
#      20     "import torch\n",
#      21     "import torchvision\n",
#      22     "from PIL import Image\n",
#      23     "from torch import nn\n",
#      24     "from torch.nn import functional as F\n",
#      25     "from torch.utils import data\n",
#      26     "from torchvision import transforms\n",
#      27     "from pathlib import Path\n",
#      28     "\n",
#      29     "nn_Module = nn.Module\n",
#      30     "\n",
#      31     "import json\n",
#      32     "import multiprocessing\n",
#      33     "import collections\n",
#      34     "import hashlib\n",
#      35     "import inspect\n",
#      36     "import math\n",
#      37     "import os\n",
#      38     "import random\n",
#      39     "import re\n",
#      40     "import shutil\n",
#      41     "import sys\n",
#      42     "import tarfile\n",
#      43     "import time\n",
#      44     "import zipfile\n",
#      45     "from collections import defaultdict\n",
#      46     "import pandas as pd\n",
#      47     "import requests\n",
#      48     "from IPython import display\n",
#      49     "from matplotlib import pyplot as plt\n",
#      50     "import matplotlib.ticker as tkr\n",
#      51     "from matplotlib.font_manager import FontProperties\n",
#      52     "from matplotlib_inline import backend_inline\n",
#      53     "\n",
#      54     "import numpy as np\n",
#      55     "import torch\n",
#      56     "import torchvision\n",
#      57     "from PIL import Image\n",
#      58     "from scipy.spatial import distance_matrix\n",
#      59     "from torch import nn\n",
#      60     "from torch.nn import functional as F\n",
#      61     "from torchvision import transforms"
#      62    ]
#      63   },
#      64   {
#      65    "cell_type": "code",
#      66    "execution_count": 2,
#      67    "id": "9a9d6dbd-2bbf-4072-b778-e4a024240af8",
#      68    "metadata": {},
#      69    "outputs": [],
#      70    "source": [
#      71     "nlinumpy = lambda x, *args, **kwargs: x.detach().numpy(*args, **kwargs)\n",
#      72     "nlito = lambda x, *args, **kwargs: x.to(*args, **kwargs)\n",
#      73     "size = lambda x, *args, **kwargs: x.numel(*args, **kwargs)\n",
#      74     "argmax = lambda x, *args, **kwargs: x.argmax(*args, **kwargs)\n",
#      75     "astype = lambda x, *args, **kwargs: x.type(*args, **kwargs)\n",
#      76     "reduce_sum = lambda x, *args, **kwargs: x.sum(*args, **kwargs)"
#      77    ]
#      78   },
#      79   {
#      80    "cell_type": "code",
#      81    "execution_count": 3,
#      82    "id": "e7c2cc40-35f3-44d1-b315-b3cb01aaec1c",
#      83    "metadata": {},
#      84    "outputs": [],
#      85    "source": [
#      86     "def get_dataloader_workers():\n",
#      87     "    \"\"\"Use 4 processes to read the data.\"\"\"\n",
#      88     "    return 4"
#      89    ]
#      90   },
#      91   {
#      92    "cell_type": "code",
#      93    "execution_count": 4,
#      94    "id": "a7c1e1c8-c986-48d9-9b85-7c1c8d1aa59b",
#      95    "metadata": {},
#      96    "outputs": [],
#      97    "source": [
#      98     "def download(url, folder='../data', sha1_hash=None):\n",
#      99     "    \"\"\"Download a file to folder and return the local filepath.\"\"\"\n",
#     100     "    if not url.startswith('http'):\n",
#     101     "        # For back compatability\n",
#     102     "        url, sha1_hash = DATA_HUB[url]\n",
#     103     "    os.makedirs(folder, exist_ok=True)\n",
#     104     "    fname = os.path.join(folder, url.split('/')[-1])\n",
#     105     "    # Check if hit cache\n",
#     106     "    if os.path.exists(fname) and sha1_hash:\n",
#     107     "        sha1 = hashlib.sha1()\n",
#     108     "        with open(fname, 'rb') as f:\n",
#     109     "            while True:\n",
#     110     "                data = f.read(1048576)\n",
#     111     "                if not data:\n",
#     112     "                    break\n",
#     113     "                sha1.update(data)\n",
#     114     "        if sha1.hexdigest() == sha1_hash:\n",
#     115     "            return fname\n",
#     116     "    r = requests.get(url, stream=True, verify=True)\n",
#     117     "    with open(fname, 'wb') as f:\n",
#     118     "        f.write(r.content)\n",
#     119     "    # Download\n",
#     120     "    print(f' ---> Downloaded {fname} from {url}.')\n",
#     121     "    return fname"
#     122    ]
#     123   },
#     124   {
#     125    "cell_type": "code",
#     126    "execution_count": 5,
#     127    "id": "d6483676-c4c6-449d-8511-a52b92493cab",
#     128    "metadata": {},
#     129    "outputs": [],
#     130    "source": [
#     131     "def extract_snli(fname):\n",
#     132     "    base_dir = os.path.dirname(fname)\n",
#     133     "    target_dir = os.path.join(base_dir, 'snli_1.0')\n",
#     134     "    if os.path.exists(target_dir):\n",
#     135     "        print(f' ---> snli data already extracted at {target_dir}')\n",
#     136     "        return\n",
#     137     "    os.makedirs(target_dir,exist_ok=True)\n",
#     138     "    with zipfile.ZipFile(fname, 'r') as input:\n",
#     139     "        for item in input.namelist():\n",
#     140     "            if '__MACOSX' in item:\n",
#     141     "                continue\n",
#     142     "            if '.DS_Store' in item:\n",
#     143     "                continue\n",
#     144     "            file_name = Path(item).name\n",
#     145     "            if 'Icon' in file_name:\n",
#     146     "                continue\n",
#     147     "            source = input.open(item)\n",
#     148     "            target = open(os.path.join(target_dir, file_name), \"wb\")\n",
#     149     "            with source, target:\n",
#     150     "                shutil.copyfileobj(source, target)\n",
#     151     "    print(f' ---> extracted snli data to {target_dir}')"
#     152    ]
#     153   },
#     154   {
#     155    "cell_type": "code",
#     156    "execution_count": 6,
#     157    "id": "4578560c-b26b-49bb-8916-73eb6c7db9f1",
#     158    "metadata": {},
#     159    "outputs": [],
#     160    "source": [
#     161     "def download_extract(name, folder=None):\n",
#     162     "    \"\"\"Download and extract a zip/tar file.\"\"\"\n",
#     163     "    \n",
#     164     "    fname = download(name)\n",
#     165     "    base_dir = os.path.dirname(fname)\n",
#     166     "    data_dir, ext = os.path.splitext(fname)\n",
#     167     "    if ext == '.zip':\n",
#     168     "        if 'snli_1.0.zip' in fname:\n",
#     169     "            extract_snli(fname)\n",
#     170     "        else:\n",
#     171     "            fp = zipfile.ZipFile(fname, 'r')\n",
#     172     "            fp.extractall(base_dir)\n",
#     173     "    elif ext in ('.tar', '.gz'):\n",
#     174     "        fp = tarfile.open(fname, 'r')\n",
#     175     "        fp.extractall(base_dir)\n",
#     176     "    else:\n",
#     177     "        assert False, 'Only zip/tar files can be extracted.'\n",
#     178     "    return os.path.join(base_dir, folder) if folder else data_dir"
#     179    ]
#     180   },
#     181   {
#     182    "cell_type": "code",
#     183    "execution_count": 7,
#     184    "id": "19de1583-2d64-48d9-af5b-5b6a98ecf0df",
#     185    "metadata": {},
#     186    "outputs": [],
#     187    "source": [
#     188     "def read_snli(data_dir, is_train):\n",
#     189     "    \"\"\"Read the SNLI dataset into premises, hypotheses, and labels.`\"\"\"\n",
#     190     "    \n",
#     191     "    def extract_text(s):\n",
#     192     "        # Remove information that will not be used by us\n",
#     193     "        s = re.sub('\\\\(', '', s)\n",
#     194     "        s = re.sub('\\\\)', '', s)\n",
#     195     "        # Substitute two or more consecutive whitespace with space\n",
#     196     "        s = re.sub('\\\\s{2,}', ' ', s)\n",
#     197     "        return s.strip()\n",
#     198     "    label_set = {'entailment': 0, 'contradiction': 1, 'neutral': 2}\n",
#     199     "    file_name = os.path.join(data_dir, 'snli_1.0_train.txt'\n",
#     200     "                             if is_train else 'snli_1.0_test.txt')\n",
#     201     "    with open(file_name, 'r') as f:\n",
#     202     "        rows = [row.split('\\t') for row in f.readlines()[1:]]\n",
#     203     "    premises = [extract_text(row[1]) for row in rows if row[0] in label_set]\n",
#     204     "    hypotheses = [extract_text(row[2]) for row in rows if row[0] in label_set]\n",
#     205     "    labels = [label_set[row[0]] for row in rows if row[0] in label_set]\n",
#     206     "    return premises, hypotheses, labels"
#     207    ]
#     208   },
#     209   {
#     210    "cell_type": "code",
#     211    "execution_count": 8,
#     212    "id": "10f34964-7cf3-4730-a684-6bab7299d3ef",
#     213    "metadata": {},
#     214    "outputs": [],
#     215    "source": [
#     216     "def tokenize(lines, token='word'):\n",
#     217     "    \"\"\"Split text lines into word or character tokens.`\"\"\"\n",
#     218     "    \n",
#     219     "    assert token in ('word', 'char'), 'Unknown token type: ' + token\n",
#     220     "    return [line.split() if token == 'word' else list(line) for line in lines]"
#     221    ]
#     222   },
#     223   {
#     224    "cell_type": "code",
#     225    "execution_count": 9,
#     226    "id": "4b60efd5-e2d4-4c0f-832b-b2d6e45b2937",
#     227    "metadata": {},
#     228    "outputs": [],
#     229    "source": [
#     230     "class Vocab:\n",
#     231     "    \"\"\"Vocabulary for text.\"\"\"\n",
#     232     "    def __init__(self, tokens=[], min_freq=0, reserved_tokens=[]):\n",
#     233     "        # Flatten a 2D list if needed\n",
#     234     "        if tokens and isinstance(tokens[0], list):\n",
#     235     "            tokens = [token for line in tokens for token in line]\n",
#     236     "        # Count token frequencies\n",
#     237     "        counter = collections.Counter(tokens)\n",
#     238     "        self.token_freqs = sorted(counter.items(), key=lambda x: x[1],\n",
#     239     "                                  reverse=True)\n",
#     240     "        # The list of unique tokens\n",
#     241     "        self.idx_to_token = list(sorted(set(['<unk>'] + reserved_tokens + [\n",
#     242     "            token for token, freq in self.token_freqs if freq >= min_freq])))\n",
#     243     "        self.token_to_idx = {token: idx\n",
#     244     "                             for idx, token in enumerate(self.idx_to_token)}\n",
#     245     "\n",
#     246     "    def __len__(self):\n",
#     247     "        return len(self.idx_to_token)\n",
#     248     "\n",
#     249     "    def __getitem__(self, tokens):\n",
#     250     "        if not isinstance(tokens, (list, tuple)):\n",
#     251     "            return self.token_to_idx.get(tokens, self.unk)\n",
#     252     "        return [self.__getitem__(token) for token in tokens]\n",
#     253     "\n",
#     254     "    def to_tokens(self, indices):\n",
#     255     "        if hasattr(indices, '__len__') and len(indices) > 1:\n",
#     256     "            return [self.idx_to_token[int(index)] for index in indices]\n",
#     257     "        return self.idx_to_token[indices]\n",
#     258     "\n",
#     259     "    @property\n",
#     260     "    def unk(self):  # Index for the unknown token\n",
#     261     "        return self.token_to_idx['<unk>']"
#     262    ]
#     263   },
#     264   {
#     265    "cell_type": "code",
#     266    "execution_count": 10,
#     267    "id": "479bc3d9-51a0-421c-b26a-17432275ebb6",
#     268    "metadata": {},
#     269    "outputs": [],
#     270    "source": [
#     271     "def truncate_pad(line, num_steps, padding_token):\n",
#     272     "    \"\"\"Truncate or pad sequences.\"\"\"\n",
#     273     "    if len(line) > num_steps:\n",
#     274     "        return line[:num_steps]  # Truncate\n",
#     275     "    return line + [padding_token] * (num_steps - len(line))  # Pad"
#     276    ]
#     277   },
#     278   {
#     279    "cell_type": "code",
#     280    "execution_count": 11,
#     281    "id": "ad122cb6-8967-42ff-b87d-c5e708b97824",
#     282    "metadata": {},
#     283    "outputs": [],
#     284    "source": [
#     285     "class SNLIDataset(torch.utils.data.Dataset):\n",
#     286     "    \"\"\"A customized dataset to load the SNLI dataset.\"\"\"\n",
#     287     "    \n",
#     288     "    def __init__(self, dataset, num_steps, vocab=None):\n",
#     289     "        self.num_steps = num_steps\n",
#     290     "        all_premise_tokens = tokenize(dataset[0])\n",
#     291     "        all_hypothesis_tokens = tokenize(dataset[1])\n",
#     292     "        if vocab is None:\n",
#     293     "            self.vocab = Vocab(all_premise_tokens + all_hypothesis_tokens,\n",
#     294     "                                   min_freq=5, reserved_tokens=['<pad>'])\n",
#     295     "        else:\n",
#     296     "            self.vocab = vocab\n",
#     297     "        self.premises = self._pad(all_premise_tokens)\n",
#     298     "        self.hypotheses = self._pad(all_hypothesis_tokens)\n",
#     299     "        self.labels = torch.tensor(dataset[2])\n",
#     300     "        print(' ---> read ' + str(len(self.premises)) + ' examples')\n",
#     301     "\n",
#     302     "    def _pad(self, lines):\n",
#     303     "        return torch.tensor([truncate_pad(\n",
#     304     "            self.vocab[line], self.num_steps, self.vocab['<pad>'])\n",
#     305     "                         for line in lines])\n",
#     306     "\n",
#     307     "    def __getitem__(self, idx):\n",
#     308     "        return (self.premises[idx], self.hypotheses[idx]), self.labels[idx]\n",
#     309     "\n",
#     310     "    def __len__(self):\n",
#     311     "        return len(self.premises)"
#     312    ]
#     313   },
#     314   {
#     315    "cell_type": "code",
#     316    "execution_count": 12,
#     317    "id": "f644c497-a60b-421d-8519-d80951bd5711",
#     318    "metadata": {},
#     319    "outputs": [],
#     320    "source": [
#     321     "def load_data_snli(batch_size, num_steps=50):\n",
#     322     "    \"\"\"Download the SNLI dataset and return data iterators and vocabulary.\"\"\"\n",
#     323     "    num_workers = get_dataloader_workers()\n",
#     324     "    data_dir = download_extract('SNLI')\n",
#     325     "    train_data = read_snli(data_dir, True)\n",
#     326     "    test_data = read_snli(data_dir, False)\n",
#     327     "    train_set = SNLIDataset(train_data, num_steps)\n",
#     328     "    test_set = SNLIDataset(test_data, num_steps, train_set.vocab)\n",
#     329     "    train_iter = torch.utils.data.DataLoader(train_set, batch_size,\n",
#     330     "                                             shuffle=True,\n",
#     331     "                                             num_workers=num_workers)\n",
#     332     "    test_iter = torch.utils.data.DataLoader(test_set, batch_size,\n",
#     333     "                                            shuffle=False,\n",
#     334     "                                            num_workers=num_workers)\n",
#     335     "    return train_iter, test_iter, train_set.vocab, data_dir"
#     336    ]
#     337   },
#     338   {
#     339    "cell_type": "code",
#     340    "execution_count": 13,
#     341    "id": "75811314-6b0a-4710-a5f4-6f54e4556ae3",
#     342    "metadata": {},
#     343    "outputs": [],
#     344    "source": [
#     345     "def cpu():\n",
#     346     "    \"\"\"Get the CPU device.\"\"\"\n",
#     347     "    return torch.device('cpu')\n",
#     348     "    \n",
#     349     "def gpu(i=0, gpu_type=None):\n",
#     350     "    \"\"\"Get a GPU device.\"\"\"\n",
#     351     "    if gpu_type:\n",
#     352     "        if gpu_type == \"cuda\":\n",
#     353     "            return torch.device(f'cuda:{i}')\n",
#     354     "        elif gpu_type == \"mps\":\n",
#     355     "            return torch.device(f'mps:{i}')\n",
#     356     "    # might not reach here, but in case\n",
#     357     "    return cpu()\n",
#     358     "\n",
#     359     "def num_gpus():\n",
#     360     "    \"\"\"Get the number of available GPUs.\"\"\"\n",
#     361     "    if torch.cuda.is_available():\n",
#     362     "        count = torch.cuda.device_count()\n",
#     363     "        print(f' ---> will run on nividia cuda gpu(s) count {count}')\n",
#     364     "        return \"cuda\", count\n",
#     365     "    elif torch.backends.mps.is_available():\n",
#     366     "        count = torch.mps.device_count()\n",
#     367     "        print(f' ---> will run on mps gpu(s) count {count}')\n",
#     368     "        return \"mps\", count\n",
#     369     "    else:\n",
#     370     "        print(f' ---> No gpus found. will run on device {cpu()}.')\n",
#     371     "        return None, 0\n",
#     372     "        \n",
#     373     "def try_gpu(i=0):\n",
#     374     "    \"\"\"Return gpu(i) if exists, otherwise return cpu().\"\"\"\n",
#     375     "    gpu_type, count = num_gpus()\n",
#     376     "    if gpu_type == None:\n",
#     377     "        return cpu()\n",
#     378     "    if count >= i + 1:\n",
#     379     "        return gpu(i, gpu_type)\n",
#     380     "    return cpu()\n",
#     381     "    \n",
#     382     "def try_all_gpus():\n",
#     383     "    \"\"\"Return all available GPUs, or [cpu(),] if no GPU exists.\"\"\"\n",
#     384     "    gpu_type, count = num_gpus()\n",
#     385     "    # no gpus return cpu\n",
#     386     "    if not gpu_type or count == 0:\n",
#     387     "        return [cpu(),]\n",
#     388     "    return [gpu(i, gpu_type) for i in range(count)]\n"
#     389    ]
#     390   },
#     391   {
#     392    "cell_type": "code",
#     393    "execution_count": 14,
#     394    "id": "21aa794d-add2-40aa-a11d-a9b58a0c3bd0",
#     395    "metadata": {},
#     396    "outputs": [],
#     397    "source": [
#     398     "class TokenEmbedding:\n",
#     399     "    \"\"\"Token Embedding.\"\"\"\n",
#     400     "    def __init__(self, embedding_name):\n",
#     401     "        self.idx_to_token, self.idx_to_vec = self._load_embedding(\n",
#     402     "            embedding_name)\n",
#     403     "        self.unknown_idx = 0\n",
#     404     "        self.token_to_idx = {token: idx for idx, token in\n",
#     405     "                             enumerate(self.idx_to_token)}\n",
#     406     "\n",
#     407     "    def _load_embedding(self, embedding_name):\n",
#     408     "        idx_to_token, idx_to_vec = ['<unk>'], []\n",
#     409     "        data_dir = download_extract(embedding_name)\n",
#     410     "        # GloVe website: https://nlp.stanford.edu/projects/glove/\n",
#     411     "        # fastText website: https://fasttext.cc/\n",
#     412     "        with open(os.path.join(data_dir, 'vec.txt'), 'r', encoding='cp437') as f:\n",
#     413     "            for line in f:\n",
#     414     "                elems = line.rstrip().split(' ')\n",
#     415     "                token, elems = elems[0], [float(elem) for elem in elems[1:]]\n",
#     416     "                # Skip header information, such as the top row in fastText\n",
#     417     "                if len(elems) > 1:\n",
#     418     "                    idx_to_token.append(token)\n",
#     419     "                    idx_to_vec.append(elems)\n",
#     420     "        idx_to_vec = [[0] * len(idx_to_vec[0])] + idx_to_vec\n",
#     421     "        return idx_to_token, torch.tensor(idx_to_vec)\n",
#     422     "\n",
#     423     "    def __getitem__(self, tokens):\n",
#     424     "        indices = [self.token_to_idx.get(token, self.unknown_idx)\n",
#     425     "                   for token in tokens]\n",
#     426     "        vecs = self.idx_to_vec[torch.tensor(indices)]\n",
#     427     "        return vecs\n",
#     428     "\n",
#     429     "    def __len__(self):\n",
#     430     "        return len(self.idx_to_token)"
#     431    ]
#     432   },
#     433   {
#     434    "cell_type": "code",
#     435    "execution_count": 15,
#     436    "id": "2c717e05-3894-4269-8131-9a171442e638",
#     437    "metadata": {},
#     438    "outputs": [],
#     439    "source": [
#     440     "class Timer:\n",
#     441     "    \"\"\"Record multiple running times.\"\"\"\n",
#     442     "    def __init__(self):\n",
#     443     "        self.times = []\n",
#     444     "        self.start()\n",
#     445     "\n",
#     446     "    def start(self):\n",
#     447     "        \"\"\"Start the timer.\"\"\"\n",
#     448     "        self.tik = time.time()\n",
#     449     "\n",
#     450     "    def stop(self):\n",
#     451     "        \"\"\"Stop the timer and record the time in a list.\"\"\"\n",
#     452     "        self.times.append(time.time() - self.tik)\n",
#     453     "        return self.times[-1]\n",
#     454     "\n",
#     455     "    def avg(self):\n",
#     456     "        \"\"\"Return the average time.\"\"\"\n",
#     457     "        return sum(self.times) / len(self.times)\n",
#     458     "\n",
#     459     "    def sum(self):\n",
#     460     "        \"\"\"Return the sum of time.\"\"\"\n",
#     461     "        return sum(self.times)\n",
#     462     "\n",
#     463     "    def cumsum(self):\n",
#     464     "        \"\"\"Return the accumulated time.\"\"\"\n",
#     465     "        return np.array(self.times).cumsum().tolist()\n"
#     466    ]
#     467   },
#     468   {
#     469    "cell_type": "code",
#     470    "execution_count": 16,
#     471    "id": "4512b8a6-baea-47c8-b3d6-b635d17c2231",
#     472    "metadata": {},
#     473    "outputs": [],
#     474    "source": [
#     475     "def use_svg_display():\n",
#     476     "    \"\"\"Use the svg format to display a plot in Jupyter.\"\"\"\n",
#     477     "    backend_inline.set_matplotlib_formats('svg')\n",
#     478     "\n",
#     479     "def set_figsize(figsize=(3.5, 2.5)):\n",
#     480     "    \"\"\"Set the figure size for matplotlib.\"\"\"\n",
#     481     "    use_svg_display()\n",
#     482     "    plt.rcParams['figure.figsize'] = figsize\n",
#     483     "\n",
#     484     "def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):\n",
#     485     "    \"\"\"Set the axes for matplotlib.\"\"\"\n",
#     486     "    axes.set_xlabel(xlabel), axes.set_ylabel(ylabel)\n",
#     487     "    axes.set_xscale(xscale), axes.set_yscale(yscale)\n",
#     488     "    axes.set_xlim(xlim),     axes.set_ylim(ylim)\n",
#     489     "    if legend:\n",
#     490     "        axes.legend(legend)\n",
#     491     "    axes.grid()\n"
#     492    ]
#     493   },
#     494   {
#     495    "cell_type": "code",
#     496    "execution_count": 17,
#     497    "id": "73565fb9-36a2-4880-8bf3-b65e4daca331",
#     498    "metadata": {},
#     499    "outputs": [],
#     500    "source": [
#     501     "class Animator:\n",
#     502     "    \"\"\"For plotting data in animation.\"\"\"\n",
#     503     "    def __init__(self, xlabel=None, ylabel=None, legend=None, xlim=None,\n",
#     504     "                 ylim=None, xscale='linear', yscale='linear',\n",
#     505     "                 fmts=('-', 'm--', 'g-.', 'r:'), nrows=1, ncols=1,\n",
#     506     "                 figsize=(3.5, 2.5)):\n",
#     507     "        # Incrementally plot multiple lines\n",
#     508     "        if legend is None:\n",
#     509     "            legend = []\n",
#     510     "        use_svg_display()\n",
#     511     "        self.fig, self.axes = plt.subplots(nrows, ncols, figsize=figsize)\n",
#     512     "        if nrows * ncols == 1:\n",
#     513     "            self.axes = [self.axes, ]\n",
#     514     "        # Use a lambda function to capture arguments\n",
#     515     "        self.config_axes = lambda: set_axes(\n",
#     516     "            self.axes[0], xlabel, ylabel, xlim, ylim, xscale, yscale, legend)\n",
#     517     "        self.X, self.Y, self.fmts = None, None, fmts\n",
#     518     "\n",
#     519     "    def add(self, x, y):\n",
#     520     "        # Add multiple data points into the figure\n",
#     521     "        if not hasattr(y, \"__len__\"):\n",
#     522     "            y = [y]\n",
#     523     "        n = len(y)\n",
#     524     "        if not hasattr(x, \"__len__\"):\n",
#     525     "            x = [x] * n\n",
#     526     "        if not self.X:\n",
#     527     "            self.X = [[] for _ in range(n)]\n",
#     528     "        if not self.Y:\n",
#     529     "            self.Y = [[] for _ in range(n)]\n",
#     530     "        for i, (a, b) in enumerate(zip(x, y)):\n",
#     531     "            if a is not None and b is not None:\n",
#     532     "                self.X[i].append(a)\n",
#     533     "                self.Y[i].append(b)\n",
#     534     "        self.axes[0].cla()\n",
#     535     "        for x, y, fmt in zip(self.X, self.Y, self.fmts):\n",
#     536     "            self.axes[0].plot(x, y, fmt)\n",
#     537     "        self.config_axes()\n",
#     538     "        display.display(self.fig)\n",
#     539     "        display.clear_output(wait=True)"
#     540    ]
#     541   },
#     542   {
#     543    "cell_type": "code",
#     544    "execution_count": 18,
#     545    "id": "79903a62-f400-4a9e-8eb7-f3027f15e388",
#     546    "metadata": {},
#     547    "outputs": [],
#     548    "source": [
#     549     "class Accumulator:\n",
#     550     "    \"\"\"For accumulating sums over `n` variables.\"\"\"\n",
#     551     "    def __init__(self, n):\n",
#     552     "        self.data = [0.0] * n\n",
#     553     "\n",
#     554     "    def add(self, *args):\n",
#     555     "        self.data = [a + float(b) for a, b in zip(self.data, args)]\n",
#     556     "\n",
#     557     "    def reset(self):\n",
#     558     "        self.data = [0.0] * len(self.data)\n",
#     559     "\n",
#     560     "    def __getitem__(self, idx):\n",
#     561     "        return self.data[idx]\n"
#     562    ]
#     563   },
#     564   {
#     565    "cell_type": "code",
#     566    "execution_count": 19,
#     567    "id": "5b425480-928d-4ee5-a4f3-64fd6676cd12",
#     568    "metadata": {},
#     569    "outputs": [],
#     570    "source": [
#     571     "def accuracy(y_hat, y):\n",
#     572     "    \"\"\"Compute the number of correct predictions.\"\"\"\n",
#     573     "    if len(y_hat.shape) > 1 and y_hat.shape[1] > 1:\n",
#     574     "        y_hat = argmax(y_hat, axis=1)\n",
#     575     "    cmp = astype(y_hat, y.dtype) == y\n",
#     576     "    return float(reduce_sum(astype(cmp, y.dtype)))"
#     577    ]
#     578   },
#     579   {
#     580    "cell_type": "code",
#     581    "execution_count": 20,
#     582    "id": "84a05e6a-3d28-4050-8e5e-e6bbdd79eeb8",
#     583    "metadata": {},
#     584    "outputs": [],
#     585    "source": [
#     586     "def train_in_batch(net, X, y, loss, trainer, devices):\n",
#     587     "    \"\"\"Train for a minibatch with multiple GPUs.\"\"\"\n",
#     588     "    if isinstance(X, list):\n",
#     589     "        # Required for BERT fine-tuning (to be covered later)\n",
#     590     "        X = [x.to(devices[0]) for x in X]\n",
#     591     "    else:\n",
#     592     "        X = X.to(devices[0])\n",
#     593     "    y = y.to(devices[0])\n",
#     594     "    net.train()\n",
#     595     "    trainer.zero_grad()\n",
#     596     "    pred = net(X)\n",
#     597     "    l = loss(pred, y)\n",
#     598     "    l.sum().backward()\n",
#     599     "    trainer.step()\n",
#     600     "    train_loss_sum = l.sum()\n",
#     601     "    train_acc_sum = accuracy(pred, y)\n",
#     602     "    return train_loss_sum, train_acc_sum"
#     603    ]
#     604   },
#     605   {
#     606    "cell_type": "code",
#     607    "execution_count": 21,
#     608    "id": "861948e6-a046-4262-87bf-b31eacfd5d2f",
#     609    "metadata": {},
#     610    "outputs": [],
#     611    "source": [
#     612     "def evaluate_accuracy_gpu_for_snli(net, data_iter, device):\n",
#     613     "    \"\"\"Compute the accuracy for a model on a dataset using a GPU.\"\"\"\n",
#     614     "    if isinstance(net, nn.Module):\n",
#     615     "        net.eval()  # Set the model to evaluation mode\n",
#     616     "        if not device:\n",
#     617     "            device = next(iter(net.parameters())).device\n",
#     618     "    # No. of correct predictions, no. of predictions\n",
#     619     "    metric = Accumulator(2)\n",
#     620     "\n",
#     621     "    with torch.no_grad():\n",
#     622     "        for X, y in data_iter:\n",
#     623     "            if isinstance(X, list):\n",
#     624     "                # Required for BERT Fine-tuning (to be covered later)\n",
#     625     "                X = [x.to(device) for x in X]\n",
#     626     "            else:\n",
#     627     "                X = X.to(device)\n",
#     628     "            y = y.to(device)           \n",
#     629     "            metric.add(accuracy(net(X), y), size(y))\n",
#     630     "            \n",
#     631     "    # test_accuracy, no. of predictions, No. of correct predictions, no. of wrong predictions\n",
#     632     "    return (metric[0] / metric[1], metric[1], metric[0], metric[1] - metric[0]) "
#     633    ]
#     634   },
#     635   {
#     636    "cell_type": "code",
#     637    "execution_count": 22,
#     638    "id": "d40c5465-a5c1-416e-87fa-36025b12c63e",
#     639    "metadata": {},
#     640    "outputs": [],
#     641    "source": [
#     642     "def train_and_evaluate(net, train_iter, test_iter, loss, trainer, num_epochs, devices):\n",
#     643     "    \"\"\"Train a model with multiple GPUs.\"\"\"\n",
#     644     "    \n",
#     645     "    print(\" ---> started training model ... \")\n",
#     646     "    timer, num_batches = Timer(), len(train_iter)\n",
#     647     "    animator = Animator(xlabel='epoch', xlim=[1, num_epochs], ylim=[0, 1],\n",
#     648     "                            legend=['train loss', 'train accuracy', 'test acccuracy'])\n",
#     649     "    net = nn.DataParallel(net, device_ids=devices).to(devices[0])\n",
#     650     "    for epoch in range(num_epochs):\n",
#     651     "        # Sum of training loss, sum of training accuracy, no. of examples,\n",
#     652     "        # no. of predictions\n",
#     653     "        metric = Accumulator(4)\n",
#     654     "        for i, (features, labels) in enumerate(train_iter):\n",
#     655     "            timer.start()\n",
#     656     "            l, acc = train_in_batch(\n",
#     657     "                net, features, labels, loss, trainer, devices)\n",
#     658     "            metric.add(l, acc, labels.shape[0], labels.numel())\n",
#     659     "            timer.stop()\n",
#     660     "            if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:\n",
#     661     "                animator.add(epoch + (i + 1) / num_batches,\n",
#     662     "                             (metric[0] / metric[2], metric[1] / metric[3],\n",
#     663     "                              None))\n",
#     664     "        test_acc, test_num_of_examples, test_passed, test_failed = evaluate_accuracy_gpu_for_snli(net, test_iter, devices[0])\n",
#     665     "        animator.add(epoch + 1, (None, None, test_acc))\n",
#     666     "        \n",
#     667     "    test_loss = 1 - test_acc\n",
#     668     "    training, test, results = dict(), dict(), dict()\n",
#     669     "    training['total_examples'], test['total_examples'] = metric[2] , test_num_of_examples\n",
#     670     "    training['passed'], test['passed'] = metric[1], test_passed\n",
#     671     "    training['failed'], test['failed'] = metric[2] - metric[1], test_failed\n",
#     672     "    training['accuracy'], test['accuracy'] = int((metric[1] * 100) / metric[3]), int(test_acc * 100)\n",
#     673     "    training['loss'], test['loss'] = f'{metric[0] / metric[2]:.3f}', f'{test_loss:.3f}'\n",
#     674     "    results['training'] = training\n",
#     675     "    results['test'] = test\n",
#     676     "    print(results)\n",
#     677     "    return results\n",
#     678     "    "
#     679    ]
#     680   },
#     681   {
#     682    "cell_type": "code",
#     683    "execution_count": 23,
#     684    "id": "777e7c73-dd91-4134-962e-23e3e252113b",
#     685    "metadata": {},
#     686    "outputs": [],
#     687    "source": [
#     688     "class MaskLM(nn.Module):\n",
#     689     "    \"\"\"The masked language model task of BERT.`\"\"\"\n",
#     690     "    def __init__(self, vocab_size, num_hiddens, **kwargs):\n",
#     691     "        super(MaskLM, self).__init__(**kwargs)\n",
#     692     "        self.mlp = nn.Sequential(nn.LazyLinear(num_hiddens),\n",
#     693     "                                 nn.ReLU(),\n",
#     694     "                                 nn.LayerNorm(num_hiddens),\n",
#     695     "                                 nn.LazyLinear(vocab_size))\n",
#     696     "\n",
#     697     "    def forward(self, X, pred_positions):\n",
#     698     "        num_pred_positions = pred_positions.shape[1]\n",
#     699     "        pred_positions = pred_positions.reshape(-1)\n",
#     700     "        batch_size = X.shape[0]\n",
#     701     "        batch_idx = torch.arange(0, batch_size)\n",
#     702     "        # Suppose that `batch_size` = 2, `num_pred_positions` = 3, then\n",
#     703     "        # `batch_idx` is `torch.tensor([0, 0, 0, 1, 1, 1])`\n",
#     704     "        batch_idx = torch.repeat_interleave(batch_idx, num_pred_positions)\n",
#     705     "        masked_X = X[batch_idx, pred_positions]\n",
#     706     "        masked_X = masked_X.reshape((batch_size, num_pred_positions, -1))\n",
#     707     "        mlm_Y_hat = self.mlp(masked_X)\n",
#     708     "        return mlm_Y_hat"
#     709    ]
#     710   },
#     711   {
#     712    "cell_type": "code",
#     713    "execution_count": 24,
#     714    "id": "d5980dc8-f390-4f92-96dc-75efc51c6e17",
#     715    "metadata": {},
#     716    "outputs": [],
#     717    "source": [
#     718     "def masked_softmax(X, valid_lens):\n",
#     719     "    \"\"\"Perform softmax operation by masking elements on the last axis.\"\"\"\n",
#     720     "    # X: 3D tensor, valid_lens: 1D or 2D tensor\n",
#     721     "    def _sequence_mask(X, valid_len, value=0):\n",
#     722     "        maxlen = X.size(1)\n",
#     723     "        mask = torch.arange((maxlen), dtype=torch.float32,\n",
#     724     "                            device=X.device)[None, :] < valid_len[:, None]\n",
#     725     "        X[~mask] = value\n",
#     726     "        return X\n",
#     727     "\n",
#     728     "    if valid_lens is None:\n",
#     729     "        return nn.functional.softmax(X, dim=-1)\n",
#     730     "    else:\n",
#     731     "        shape = X.shape\n",
#     732     "        if valid_lens.dim() == 1:\n",
#     733     "            valid_lens = torch.repeat_interleave(valid_lens, shape[1])\n",
#     734     "        else:\n",
#     735     "            valid_lens = valid_lens.reshape(-1)\n",
#     736     "        # On the last axis, replace masked elements with a very large negative\n",
#     737     "        # value, whose exponentiation outputs 0\n",
#     738     "        X = _sequence_mask(X.reshape(-1, shape[-1]), valid_lens, value=-1e6)\n",
#     739     "        return nn.functional.softmax(X.reshape(shape), dim=-1)\n"
#     740    ]
#     741   },
#     742   {
#     743    "cell_type": "code",
#     744    "execution_count": 25,
#     745    "id": "72eda387-7bc9-485c-ba4a-6f9303660523",
#     746    "metadata": {},
#     747    "outputs": [],
#     748    "source": [
#     749     "class DotProductAttention(nn.Module):\n",
#     750     "    \"\"\"Scaled dot product attention.\"\"\"\n",
#     751     "    def __init__(self, dropout):\n",
#     752     "        super().__init__()\n",
#     753     "        self.dropout = nn.Dropout(dropout)\n",
#     754     "\n",
#     755     "    # Shape of queries: (batch_size, no. of queries, d)\n",
#     756     "    # Shape of keys: (batch_size, no. of key-value pairs, d)\n",
#     757     "    # Shape of values: (batch_size, no. of key-value pairs, value dimension)\n",
#     758     "    # Shape of valid_lens: (batch_size,) or (batch_size, no. of queries)\n",
#     759     "    def forward(self, queries, keys, values, valid_lens=None):\n",
#     760     "        d = queries.shape[-1]\n",
#     761     "        # Swap the last two dimensions of keys with keys.transpose(1, 2)\n",
#     762     "        scores = torch.bmm(queries, keys.transpose(1, 2)) / math.sqrt(d)\n",
#     763     "        self.attention_weights = masked_softmax(scores, valid_lens)\n",
#     764     "        return torch.bmm(self.dropout(self.attention_weights), values)"
#     765    ]
#     766   },
#     767   {
#     768    "cell_type": "code",
#     769    "execution_count": 26,
#     770    "id": "2a1d2637-35ba-448f-9c8f-7fec1be1a169",
#     771    "metadata": {},
#     772    "outputs": [],
#     773    "source": [
#     774     "class NLIHyperParameters:\n",
#     775     "    \"\"\"The base class of hyperparameters.\"\"\"\n",
#     776     "    def save_hyperparameters(self, ignore=[]):\n",
#     777     "        raise NotImplemented\n",
#     778     "\n",
#     779     "    def save_hyperparameters(self, ignore=[]):\n",
#     780     "        \"\"\"Save function arguments into class attributes.`\"\"\"\n",
#     781     "        frame = inspect.currentframe().f_back\n",
#     782     "        _, _, _, local_vars = inspect.getargvalues(frame)\n",
#     783     "        self.hparams = {k:v for k, v in local_vars.items()\n",
#     784     "                        if k not in set(ignore+['self']) and not k.startswith('_')}\n",
#     785     "        for k, v in self.hparams.items():\n",
#     786     "            setattr(self, k, v)"
#     787    ]
#     788   },
#     789   {
#     790    "cell_type": "code",
#     791    "execution_count": 27,
#     792    "id": "8dec1ae0-8dc6-4cb2-89a1-a794b8c8d77b",
#     793    "metadata": {},
#     794    "outputs": [],
#     795    "source": [
#     796     "class ProgressBoard(NLIHyperParameters):\n",
#     797     "    \"\"\"The board that plots data points in animation\"\"\"\n",
#     798     "    def __init__(self, xlabel=None, ylabel=None, xlim=None,\n",
#     799     "                 ylim=None, xscale='linear', yscale='linear',\n",
#     800     "                 ls=['-', '--', '-.', ':'], colors=['C0', 'C1', 'C2', 'C3'],\n",
#     801     "                 fig=None, axes=None, figsize=(3.5, 2.5), display=True):\n",
#     802     "        self.save_hyperparameters()\n",
#     803     "\n",
#     804     "    def draw(self, x, y, label, every_n=1):\n",
#     805     "        raise NotImplemented\n",
#     806     "\n",
#     807     "    def draw(self, x, y, label, every_n=1):\n",
#     808     "        Point = collections.namedtuple('Point', ['x', 'y'])\n",
#     809     "        if not hasattr(self, 'raw_points'):\n",
#     810     "            self.raw_points = collections.OrderedDict()\n",
#     811     "            self.data = collections.OrderedDict()\n",
#     812     "        if label not in self.raw_points:\n",
#     813     "            self.raw_points[label] = []\n",
#     814     "            self.data[label] = []\n",
#     815     "        points = self.raw_points[label]\n",
#     816     "        line = self.data[label]\n",
#     817     "        points.append(Point(x, y))\n",
#     818     "        if len(points) != every_n:\n",
#     819     "            return\n",
#     820     "        mean = lambda x: sum(x) / len(x)\n",
#     821     "        line.append(Point(mean([p.x for p in points]),\n",
#     822     "                          mean([p.y for p in points])))\n",
#     823     "        points.clear()\n",
#     824     "        if not self.display:\n",
#     825     "            return\n",
#     826     "        use_svg_display()\n",
#     827     "        if self.fig is None:\n",
#     828     "            self.fig = plt.figure(figsize=self.figsize)\n",
#     829     "        plt_lines, labels = [], []\n",
#     830     "        for (k, v), ls, color in zip(self.data.items(), self.ls, self.colors):\n",
#     831     "            plt_lines.append(plt.plot([p.x for p in v], [p.y for p in v],\n",
#     832     "                                          linestyle=ls, color=color)[0])\n",
#     833     "            labels.append(k)\n",
#     834     "        axes = self.axes if self.axes else plt.gca()\n",
#     835     "        if self.xlim: axes.set_xlim(self.xlim)\n",
#     836     "        if self.ylim: axes.set_ylim(self.ylim)\n",
#     837     "        if not self.xlabel: self.xlabel = self.x\n",
#     838     "        axes.set_xlabel(self.xlabel)\n",
#     839     "        axes.set_ylabel(self.ylabel)\n",
#     840     "        axes.set_xscale(self.xscale)\n",
#     841     "        axes.set_yscale(self.yscale)\n",
#     842     "        axes.legend(plt_lines, labels)\n",
#     843     "        display.display(self.fig)\n",
#     844     "        display.clear_output(wait=True)"
#     845    ]
#     846   },
#     847   {
#     848    "cell_type": "code",
#     849    "execution_count": 28,
#     850    "id": "bc9f3e26-4e76-40a0-a86f-458e01c7960e",
#     851    "metadata": {},
#     852    "outputs": [],
#     853    "source": [
#     854     "class NLIModule(nn.Module, NLIHyperParameters):\n",
#     855     "    \"\"\"The base class of models\"\"\"\n",
#     856     "    def __init__(self, plot_train_per_epoch=2, plot_valid_per_epoch=1):\n",
#     857     "        super().__init__()\n",
#     858     "        self.save_hyperparameters()\n",
#     859     "        self.board = ProgressBoard()\n",
#     860     "\n",
#     861     "    def loss(self, y_hat, y):\n",
#     862     "        raise NotImplementedError\n",
#     863     "\n",
#     864     "    def forward(self, X):\n",
#     865     "        assert hasattr(self, 'net'), 'Neural network is defined'\n",
#     866     "        return self.net(X)\n",
#     867     "\n",
#     868     "    def plot(self, key, value, train):\n",
#     869     "        \"\"\"Plot a point in animation.\"\"\"\n",
#     870     "        assert hasattr(self, 'trainer'), 'Trainer is not inited'\n",
#     871     "        self.board.xlabel = 'epoch'\n",
#     872     "        if train:\n",
#     873     "            x = self.trainer.train_batch_idx / \\\n",
#     874     "                self.trainer.num_train_batches\n",
#     875     "            n = self.trainer.num_train_batches / \\\n",
#     876     "                self.plot_train_per_epoch\n",
#     877     "        else:\n",
#     878     "            x = self.trainer.epoch + 1\n",
#     879     "            n = self.trainer.num_val_batches / \\\n",
#     880     "                self.plot_valid_per_epoch\n",
#     881     "        self.board.draw(x, nlinumpy(nlito(value, cpu())),\n",
#     882     "                        ('train_' if train else 'val_') + key,\n",
#     883     "                        every_n=int(n))\n",
#     884     "\n",
#     885     "    def training_step(self, batch):\n",
#     886     "        l = self.loss(self(*batch[:-1]), batch[-1])\n",
#     887     "        self.plot('loss', l, train=True)\n",
#     888     "        return l\n",
#     889     "\n",
#     890     "    def validation_step(self, batch):\n",
#     891     "        l = self.loss(self(*batch[:-1]), batch[-1])\n",
#     892     "        self.plot('loss', l, train=False)\n",
#     893     "\n",
#     894     "    def configure_optimizers(self):\n",
#     895     "        raise NotImplementedError\n",
#     896     "\n",
#     897     "    def configure_optimizers(self):\n",
#     898     "        return torch.optim.SGD(self.parameters(), lr=self.lr)\n",
#     899     "\n",
#     900     "    def apply_init(self, inputs, init=None):\n",
#     901     "        self.forward(*inputs)\n",
#     902     "        if init is not None:\n",
#     903     "            self.net.apply(init)"
#     904    ]
#     905   },
#     906   {
#     907    "cell_type": "code",
#     908    "execution_count": 29,
#     909    "id": "e93e93e1-ee54-4f16-a270-0ee25fd4a87b",
#     910    "metadata": {},
#     911    "outputs": [],
#     912    "source": [
#     913     "class MultiHeadAttention(NLIModule):\n",
#     914     "    \"\"\"Multi-head attention.\"\"\"\n",
#     915     "    def __init__(self, num_hiddens, num_heads, dropout, bias=False, **kwargs):\n",
#     916     "        super().__init__()\n",
#     917     "        self.num_heads = num_heads\n",
#     918     "        self.attention = DotProductAttention(dropout)\n",
#     919     "        self.W_q = nn.LazyLinear(num_hiddens, bias=bias)\n",
#     920     "        self.W_k = nn.LazyLinear(num_hiddens, bias=bias)\n",
#     921     "        self.W_v = nn.LazyLinear(num_hiddens, bias=bias)\n",
#     922     "        self.W_o = nn.LazyLinear(num_hiddens, bias=bias)\n",
#     923     "\n",
#     924     "    def forward(self, queries, keys, values, valid_lens):\n",
#     925     "        # Shape of queries, keys, or values:\n",
#     926     "        # (batch_size, no. of queries or key-value pairs, num_hiddens)\n",
#     927     "        # Shape of valid_lens: (batch_size,) or (batch_size, no. of queries)\n",
#     928     "        # After transposing, shape of output queries, keys, or values:\n",
#     929     "        # (batch_size * num_heads, no. of queries or key-value pairs,\n",
#     930     "        # num_hiddens / num_heads)\n",
#     931     "        queries = self.transpose_qkv(self.W_q(queries))\n",
#     932     "        keys = self.transpose_qkv(self.W_k(keys))\n",
#     933     "        values = self.transpose_qkv(self.W_v(values))\n",
#     934     "\n",
#     935     "        if valid_lens is not None:\n",
#     936     "            # On axis 0, copy the first item (scalar or vector) for num_heads\n",
#     937     "            # times, then copy the next item, and so on\n",
#     938     "            valid_lens = torch.repeat_interleave(\n",
#     939     "                valid_lens, repeats=self.num_heads, dim=0)\n",
#     940     "\n",
#     941     "        # Shape of output: (batch_size * num_heads, no. of queries,\n",
#     942     "        # num_hiddens / num_heads)\n",
#     943     "        output = self.attention(queries, keys, values, valid_lens)\n",
#     944     "        # Shape of output_concat: (batch_size, no. of queries, num_hiddens)\n",
#     945     "        output_concat = self.transpose_output(output)\n",
#     946     "        return self.W_o(output_concat)\n",
#     947     "        \n",
#     948     "    def transpose_qkv(self, X):\n",
#     949     "        \"\"\"Transposition for parallel computation of multiple attention heads.\"\"\"\n",
#     950     "        # Shape of input X: (batch_size, no. of queries or key-value pairs,\n",
#     951     "        # num_hiddens). Shape of output X: (batch_size, no. of queries or\n",
#     952     "        # key-value pairs, num_heads, num_hiddens / num_heads)\n",
#     953     "        X = X.reshape(X.shape[0], X.shape[1], self.num_heads, -1)\n",
#     954     "        # Shape of output X: (batch_size, num_heads, no. of queries or key-value\n",
#     955     "        # pairs, num_hiddens / num_heads)\n",
#     956     "        X = X.permute(0, 2, 1, 3)\n",
#     957     "        # Shape of output: (batch_size * num_heads, no. of queries or key-value\n",
#     958     "        # pairs, num_hiddens / num_heads)\n",
#     959     "        return X.reshape(-1, X.shape[2], X.shape[3])\n",
#     960     "\n",
#     961     "    def transpose_output(self, X):\n",
# ...
#    1171     "    def __len__(self):\n",
#    1172     "        return len(self.all_token_ids)\n"
#    1173    ]
#    1174   },
#    1175   {
#    1176    "cell_type": "code",
#    1177    "execution_count": 38,
#    1178    "id": "762df892-c06d-42f4-97b4-2965981fa2bf",
#    1179    "metadata": {},
#    1180    "outputs": [],
#    1181    "source": [
#    1182     "class BERTClassifier(nn.Module):\n",
#    1183     "    def __init__(self, bert):\n",
#    1184     "        super(BERTClassifier, self).__init__()\n",
#    1185     "        self.encoder = bert.encoder\n",
#    1186     "        self.hidden = bert.hidden\n",
#    1187     "        self.output = nn.LazyLinear(3)\n",
#    1188     "    def forward(self, inputs):\n",
#    1189     "        tokens_X, segments_X, valid_lens_x = inputs\n",
#    1190     "        encoded_X = self.encoder(tokens_X, segments_X, valid_lens_x)\n",
#    1191     "        return self.output(self.hidden(encoded_X[:, 0, :]))"
#    1192    ]
#    1193   },
#    1194   {
#    1195    "cell_type": "code",
#    1196    "execution_count": 39,
#    1197    "id": "61b11681-4ff2-4237-996c-096e3ea9ca0a",
#    1198    "metadata": {},
#    1199    "outputs": [],
#    1200    "source": [
#    1201     "def predict_bert(net, vocab, premise, hypothesis):\n",
#    1202     "    \"\"\"Predict the logical relationship between the premise and hypothesis.\"\"\"\n",
#    1203     "    # Set the model to evaluation mode\n",
#    1204     "    net.eval()\n",
#    1205     "    device = next(iter(net.parameters())).device\n",
#    1206     "    premise_tokens =  [elem.split('.')[0] if '.' in elem else elem for elem in premise.rstrip().split(' ')] + ['.']\n",
#    1207     "    hypothesis_tokens =  [elem.split('.')[0] if '.' in elem else elem for elem in hypothesis.rstrip().split(' ')] + ['.']\n",
#    1208     "    tokens, segments = get_tokens_and_segments(premise_tokens, hypothesis_tokens)\n",
#    1209     "    token_ids = torch.tensor(vocab[tokens], device=device).unsqueeze(0)\n",
#    1210     "    segments = torch.tensor(segments, device=device).unsqueeze(0)\n",
#    1211     "    valid_len = torch.tensor(len(tokens), device=device).unsqueeze(0)\n",
#    1212     "    label = torch.argmax(net((token_ids,segments,valid_len)), dim=1)\n",
#    1213     "    return 'entailment' if label == 0 else 'contradiction' if label == 1 else 'neutral'"
#    1214    ]
#    1215   },
#    1216   {
#    1217    "cell_type": "code",
#    1218    "execution_count": 40,
#    1219    "id": "7471c275-8794-4f61-917b-b49e3f2839df",
#    1220    "metadata": {},
#    1221    "outputs": [],
#    1222    "source": [
#    1223     "def format_data(data, mode=None):\n",
#    1224     "    if mode:\n",
#    1225     "        _mode = data[mode]\n",
#    1226     "        return [_mode['total_examples'], _mode['passed'], _mode['failed'], _mode['accuracy'], _mode['loss']]\n",
#    1227     "    else:\n",
#    1228     "        training = data['training']\n",
#    1229     "        test = data['test']\n",
#    1230     "        return [ [\"Training\", training['total_examples'], training['passed'], training['failed'], f\"{training['accuracy']}%\", training['loss'] ],\n",
#    1231     "                 [\"Test\", test['total_examples'], test['passed'], test['failed'], f\"{test['accuracy']}%\", test['loss']] ]"
#    1232    ]
#    1233   },
#    1234   {
#    1235    "cell_type": "code",
#    1236    "execution_count": 41,
#    1237    "id": "3d727c19-0c7f-43b0-857c-32770bd937c2",
#    1238    "metadata": {},
#    1239    "outputs": [],
#    1240    "source": [
#    1241     "def format_kb(x, pos):\n",
#    1242     "    \"\"\"Formats the y-axis values to K.\"\"\"\n",
#    1243     "    return f'{x // 1000} K'"
#    1244    ]
#    1245   },
#    1246   {
#    1247    "cell_type": "code",
#    1248    "execution_count": 42,
#    1249    "id": "e95ff1e9-46a6-4e8c-9cc2-6ec9ca65d49f",
#    1250    "metadata": {},
#    1251    "outputs": [],
#    1252    "source": [
#    1253     "def display_results(data, title=\"notitle\"):\n",
#    1254     "    tabular_data = format_data(data)\n",
#    1255     "    training_data = format_data(data, 'training')\n",
#    1256     "    test_data = format_data(data, 'test')\n",
#    1257     "    columns = [\"Mode\", \"Total examples\", \"Passed\", \"Failed\", \"Accuracy\", \"Loss\"]\n",
#    1258     "    modes = [\"Training\", \"Test\"]\n",
#    1259     "    subgroups = [\"Passed\", \"Failed\"]\n",
#    1260     "    colors = [ [\"#FFFF00\",\"w\",\"w\",\"w\",\"w\", \"w\"], [\"#FFFF00\",\"w\",\"w\",\"w\",\"w\", \"w\"]]\n",
#    1261     "    df = pd.DataFrame(tabular_data, columns=columns)\n",
#    1262     "\n",
#    1263     "    fig = plt.figure(figsize=(8.5,5))\n",
#    1264     "\n",
#    1265     "    for i in range(1):\n",
#    1266     "        ax = plt.subplot2grid((2,2), (0,2*i), colspan=2)\n",
#    1267     "        # Hide axes\n",
#    1268     "        fig.patch.set_visible(False)\n",
#    1269     "        ax.axis('off')\n",
#    1270     "        ax.axis('tight')\n",
#    1271     "        table = ax.table(cellText=df.values, colLabels=df.columns, loc='center', cellLoc='center', cellColours=colors)\n",
#    1272     "        for (row, col), cell in table.get_celld().items():\n",
#    1273     "            if (row == 0) or (col == -1):\n",
#    1274     "                cell.set_text_props(fontproperties=FontProperties(weight='bold'))\n",
#    1275     "        ax.set_title(title)\n",
#    1276     "    \n",
#    1277     "    row2 = 5\n",
#    1278     "    # Define bar width and positions\n",
#    1279     "    bar_width = .20\n",
#    1280     "    x_positions = np.arange(1)\n",
#    1281     "    normalized_training_data = [training_data[1], training_data[2]]\n",
#    1282     "    normalized_test_data = [test_data[1], test_data[2]]\n",
#    1283     "    for j in range(row2-1):\n",
#    1284     "        ax = plt.subplot2grid((2,2*row2), (1,2*j+1), colspan=2)\n",
#    1285     "        if j == 0:\n",
#    1286     "            for i, subgroup in enumerate(subgroups):\n",
#    1287     "                ax.bar(x_positions + i * bar_width, normalized_training_data[i],bar_width, label=subgroup)\n",
#    1288     "            ax.set_xticks(x_positions + bar_width / 2)\n",
#    1289     "            ax.set_xticklabels([\"Training\"])\n",
#    1290     "            ax.yaxis.set_major_formatter(tkr.FuncFormatter(format_kb))\n",
#    1291     "        elif j == 1:\n",
#    1292     "            for i, subgroup in enumerate(subgroups):\n",
#    1293     "                ax.bar(x_positions + i * bar_width, normalized_test_data[i],bar_width, label=subgroup)\n",
#    1294     "            # Customize the plot\n",
#    1295     "            ax.set_xticks(x_positions + bar_width / 2)\n",
#    1296     "            ax.set_xticklabels([\"Test\"])\n",
#    1297     "            ax.yaxis.set_major_formatter(tkr.FuncFormatter(format_kb))\n",
#    1298     "        elif j == 2:\n",
#    1299     "            ax.pie([training_data[1], training_data[2]], labels=[\"passed\", \"failed\"], autopct='%1.1f%%', startangle=90)\n",
#    1300     "            ax.set_title('Training')\n",
#    1301     "        else:\n",
#    1302     "            ax.pie([test_data[1], test_data[2]], labels=[\"passed\", \"failed\"], autopct='%1.1f%%', startangle=90)\n",
#    1303     "            ax.set_title('Test') \n",
#    1304     "        \n",
#    1305     "    # Adjust layout to prevent overlapping titles\n",
#    1306     "    plt.tight_layout()\n",
#    1307     "    plt.savefig(f'images/{title}_results.png')\n",
#    1308     "    plt.show()\n",
#    1309     "    plt.close()\n"
#    1310    ]
#    1311   },
#    1312   {
#    1313    "cell_type": "code",
#    1314    "execution_count": 43,
#    1315    "id": "47ddb30f-18c6-43ef-bac9-ffff5f2844f5",
#    1316    "metadata": {},
#    1317    "outputs": [],
#    1318    "source": [
#    1319     "def compare_results(glove, bert_base, bert_small, mode=\"test\"):\n",
#    1320     "    title = f'Comparsion of {mode} results accross GloVe, BERT.Base, Bert.Small embeddings'\n",
#    1321     "    \n",
#    1322     "    glove_data = format_data(glove, mode)\n",
#    1323     "    bert_base_data = format_data(bert_base, mode)\n",
#    1324     "    bert_small_data = format_data(bert_small, mode)\n",
#    1325     "\n",
#    1326     "    columns = [\"Embeddings Type\", \"Total examples\", \"Passed\", \"Failed\", \"Accuracy\", \"Loss\"]\n",
#    1327     "    embeedings = [\"GloVe\", \"BERT.Base\", \"BERT.Small\"]\n",
#    1328     "    labels = [\"Passed\", \"Failed\"]\n",
#    1329     "    ccolors = [ [\"#FFFF00\",\"w\",\"w\",\"w\",\"w\", \"w\"], [\"#FFFF00\",\"w\",\"w\",\"w\",\"w\", \"w\"], [\"#FFFF00\",\"w\",\"w\",\"w\",\"w\", \"w\"]]\n",
#    1330     "    row1, row2 = 1,4\n",
#    1331     "    bar_width = .20\n",
#    1332     "    x_positions = np.arange(2)\n",
#    1333     "    \n",
#    1334     "    fig = plt.figure(figsize=(10,5))\n",
#    1335     "\n",
#    1336     "    for i in range(row1):\n",
#    1337     "        ax = plt.subplot2grid((2,2*row1), (0,2*i), colspan=2)\n",
#    1338     "        df = pd.DataFrame([[\"GloVe\"] + glove_data, [\"BERT.Base\"] + bert_base_data, [\"BERT.Small\"] + bert_small_data], columns=columns)\n",
#    1339     "        fig.patch.set_visible(False)\n",
#    1340     "        ax.axis('off')\n",
#    1341     "        ax.axis('tight')\n",
#    1342     "        table = ax.table(cellText=df.values, colLabels=df.columns, loc='center', cellLoc='center', cellColours=ccolors)\n",
#    1343     "        ax.set_title(title)\n",
#    1344     "        for (row, col), cell in table.get_celld().items():\n",
#    1345     "            if (row == 0) or (col == -1):\n",
#    1346     "                cell.set_text_props(fontproperties=FontProperties(weight='bold'))\n",
#    1347     "    \n",
#    1348     "    for i in range(row2-1):\n",
#    1349     "        ax = plt.subplot2grid((2,2*row2), (1,2*i+1), colspan=2)\n",
#    1350     "        if i == 0:\n",
#    1351     "            data = [ [glove_data[1], glove_data[2]] , [ bert_base_data[1], bert_base_data[2] ], [bert_small_data[1], bert_small_data[2]]]\n",
#    1352     "\n",
#    1353     "            for j, subgroup in enumerate(embeedings):\n",
#    1354     "                ax.bar(x_positions + j * bar_width, data[j], bar_width, label=subgroup)\n",
#    1355     "            ax.set_xticks(x_positions + bar_width / 2)\n",
#    1356     "            ax.set_xticklabels(labels)\n",
#    1357     "            ax.yaxis.set_major_formatter(tkr.FuncFormatter(format_kb))\n",
#    1358     "            ax.legend()\n",
#    1359     "        elif i == 1: # pie passed\n",
#    1360     "            ax.pie([glove_data[1], bert_base_data[1], bert_small_data[1]], labels=embeedings, autopct='%1.1f%%', startangle=90)\n",
#    1361     "            ax.set_title('Passed')\n",
#    1362     "        else: # pie failed\n",
#    1363     "            ax.pie([glove_data[2], bert_base_data[2], bert_small_data[2]], labels=embeedings, autopct='%1.1f%%', startangle=90)\n",
#    1364     "            ax.set_title('Failed')\n",
#    1365     "            \n",
#    1366     "    \n",
#    1367     "    plt.tight_layout()\n",
#    1368     "    plt.savefig(f'images/{title}_results.png')\n",
#    1369     "    plt.show()\n",
#    1370     "    plt.close()"
#    1371    ]
#    1372   },
#    1373   {
#    1374    "cell_type": "code",
#    1375    "execution_count": 44,
#    1376    "id": "4406759f-aec5-4fdf-acd6-5659cffb1f47",
#    1377    "metadata": {},
#    1378    "outputs": [],
#    1379    "source": [
#    1380     "def predict_glove(net, vocab, premise, hypothesis):\n",
#    1381     "    \"\"\"Predict the logical relationship between the premise and hypothesis.\"\"\"\n",
#    1382     "    net.eval()\n",
#    1383     "    premise = torch.tensor(vocab[premise], device=try_gpu())\n",
#    1384     "    hypothesis = torch.tensor(vocab[hypothesis], device= try_gpu())\n",
#    1385     "    label = torch.argmax(net([premise.reshape((1, -1)), hypothesis.reshape((1, -1))]), dim=1)\n",
#    1386     "    return 'entailment' if label == 0 else 'contradiction' if label == 1 else 'neutral'"
#    1387    ]
#    1388   },
#    1389   {
#    1390    "cell_type": "code",
#    1391    "execution_count": 45,
#    1392    "id": "ece9f90e-2900-4d18-8774-57243514baa6",
#    1393    "metadata": {},
#    1394    "outputs": [],
#    1395    "source": [
#    1396     "def unit_testing(glove_net, glove_vocab, bert_small_net, bert_small_vocab, bert_base_net, bert_base_vocab):\n",
#    1397     "    unit_test_data = [\n",
#    1398     "        {\n",
#    1399     "            'Premise:': 'A man is running the coding example.',\n",
#    1400     "            'Hypothesis:': 'The man is sleeping.',\n",
#    1401     "            'Expected Result': 'contradiction',\n",
#    1402     "            'Glove Emeddings Actual Result': predict_glove(glove_net, glove_vocab, ['A', 'man', 'is', 'running', 'code', 'example', '.'], ['The', 'man', 'is', 'sleeping', '.']),\n",
#    1403     "            'Bert.Small Embedings Actual Result': predict_bert(bert_small_net, bert_small_vocab, ['A', 'man', 'is', 'running', 'code', 'example', '.'], ['The', 'man', 'is', 'sleeping', '.']),\n",
#    1404     "            'Bert.Base Embedings Actual Result': predict_bert(bert_base_net, bert_base_vocab, ['A', 'man', 'is', 'running', 'code', 'example', '.'], ['The', 'man', 'is', 'sleeping', '.'])\n",
#    1405     "        },\n",
#    1406     "        {\n",
#    1407     "            'Premise:': 'I do need sleep.',\n",
#    1408     "            'Hypothesis:': 'I am tired',\n",
#    1409     "            'Expected Result': 'entilement',\n",
#    1410     "            'Glove Emeddings Actual Result': predict_glove(glove_net, glove_vocab,  ['I', 'do', 'need', 'sleep', '.'], ['I', 'iam', 'tired', '.']),\n",
#    1411     "            'Bert.Small Embedings Actual Result': predict_bert(bert_small_net, bert_small_vocab,  ['I', 'do', 'need', 'sleep', '.'], ['I', 'iam', 'tired', '.']),\n",
#    1412     "            'Bert.Base Embedings Actual Result': predict_bert(bert_base_net, bert_base_vocab,  ['I', 'do', 'need', 'sleep', '.'], ['I', 'iam', 'tired', '.'])\n",
#    1413     "        },\n",
#    1414     "        {\n",
#    1415     "            'Premise:': 'The musicians are performing for us.',\n",
#    1416     "            'Hypothesis:': 'The musicians are famous.',\n",
#    1417     "            'Expected Result': 'neutral',\n",
#    1418     "            'Glove Emeddings Actual Result': predict_glove(glove_net, glove_vocab, ['The', 'musicians', 'are', 'performing', 'for', 'us', '.'], ['The', 'musicians', 'are', 'famous', '.']),\n",
#    1419     "            'Bert.Small Embedings Actual Result': predict_bert(bert_small_net, bert_small_vocab, ['The', 'musicians', 'are', 'performing', 'for', 'us', '.'], ['The', 'musicians', 'are', 'famous', '.']),\n",
#    1420     "            'Bert.Base Embedings Actual Result': predict_bert(bert_base_net, bert_base_vocab, ['The', 'musicians', 'are', 'performing', 'for', 'us', '.'], ['The', 'musicians', 'are', 'famous', '.'])\n",
#    1421     "        }\n",
#    1422     "    ]\n",
#    1423     "    formatted_unit_test_data = json.dumps(unit_test_data, indent=4)\n",
#    1424     "    print(\"Initial testing results\")\n",
#    1425     "    print(formatted_unit_test_data)"
#    1426    ]
#    1427   },
#    1428   {
#    1429    "cell_type": "code",
#    1430    "execution_count": null,
#    1431    "id": "01e112b3-5138-4656-8dd5-9228767228a0",
#    1432    "metadata": {},
#    1433    "outputs": [],
#    1434    "source": []
#    1435   }
#    1436  ],
#    1437  "metadata": {
#    1438   "kernelspec": {
#    1439    "display_name": "Python 3 (ipykernel)",
#    1440    "language": "python",
#    1441    "name": "python3"
#    1442   },
#    1443   "language_info": {
#    1444    "codemirror_mode": {
#    1445     "name": "ipython",
#    1446     "version": 3
#    1447    },
#    1448    "file_extension": ".py",
#    1449    "mimetype": "text/x-python",
#    1450    "name": "python",
#    1451    "nbconvert_exporter": "python",
#    1452    "pygments_lexer": "ipython3",
#    1453    "version": "3.9.21"
#    1454   }
#    1455  },
#    1456  "nbformat": 4,
#    1457  "nbformat_minor": 5
#    1458 }
#
# AttributeError: 'list' object has no attribute 'rstrip'
