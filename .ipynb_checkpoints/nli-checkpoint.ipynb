# %%
import torch
from torch import nn
from torch.nn import functional as F
import multiprocessing
# utility functions
import json
import os
from ipynb.fs.full.utilities import BERTModel, download_extract, Vocab, load_data_snli, try_all_gpus, TokenEmbedding, train_and_evaluate, BERT, get_dataloader_workers,SNLIBERTDataset, read_snli, BERTClassifier, display_results

# %% [markdown]
# #### Natural Language Inference with `Decomposable attention model with MLPs(Multi Layer Perceptrons) and GloVe embeddings`
# ![Solution Overview](images/NaturalLanguageInference.GloVe.png)
# ###### The solution will feed pretrained [GloVe](GLOVE.md) embeddings to [MLP](MLP.md) and [Attention](ATTENTION.md)

# %%
def mlp(num_inputs, num_hiddens, flatten):
    """Inputs are separately taken rather than takes a pair of them together.
       This decomposition trick leads to only m+n applications (linear complexity) 
       rather than m*n applications (quadratic complexity).
    """
    net = []
    net.append(nn.Dropout(0.2))
    net.append(nn.Linear(num_inputs, num_hiddens))
    net.append(nn.ReLU())
    if flatten:
        net.append(nn.Flatten(start_dim=1))
    net.append(nn.Dropout(0.2))
    net.append(nn.Linear(num_hiddens, num_hiddens))
    net.append(nn.ReLU())
    if flatten:
        net.append(nn.Flatten(start_dim=1))
    return nn.Sequential(*net)

# %%
class Attend(nn.Module):
    """Compute the soft alignment of hypotheses (beta) withinput premises A and 
       soft alignment of premises (alpha) with input hypotheses B.
    """
    def __init__(self, num_inputs, num_hiddens, **kwargs):
        super(Attend, self).__init__(**kwargs)
        self.f = mlp(num_inputs, num_hiddens, flatten=False)
    def forward(self, A, B):
        # Shape of `A`/`B`: (`batch_size`, no. of tokens in sequence A/B,
        # `embed_size`)
        # Shape of `f_A`/`f_B`: (`batch_size`, no. of tokens in sequence A/B,
        # `num_hiddens`)
        f_A = self.f(A)
        f_B = self.f(B)
        # Shape of `e`: (`batch_size`, no. of tokens in sequence A,
        # no. of tokens in sequence B)
        e = torch.bmm(f_A, f_B.permute(0, 2, 1))
        # Shape of `beta`: (`batch_size`, no. of tokens in sequence A,
        # `embed_size`), where sequence B is softly aligned with each token
        # (axis 1 of `beta`) in sequence A
        beta = torch.bmm(F.softmax(e, dim=-1), B)
        # Shape of `alpha`: (`batch_size`, no. of tokens in sequence B,
        # `embed_size`), where sequence A is softly aligned with each token
        # (axis 1 of `alpha`) in sequence B
        alpha = torch.bmm(F.softmax(e.permute(0, 2, 1), dim=-1), A)
        return beta, alpha

# %%
class Compare(nn.Module):
    """Compare between token 𝑖 in the premise and all the hypothesis tokens that are softly aligned with token 𝑖 and 
       compare between token 𝑗 in the hypothesis and all the premise tokens that are softly aligned with token 𝑗.
    """
    def __init__(self, num_inputs, num_hiddens, **kwargs):
        super(Compare, self).__init__(**kwargs)
        self.g = mlp(num_inputs, num_hiddens, flatten=False)
    def forward(self, A, B, beta, alpha):
        V_A = self.g(torch.cat([A, beta], dim=2))
        V_B = self.g(torch.cat([B, alpha], dim=2))
        return V_A, V_B

# %%
class Aggregate(nn.Module):
    """With two comparision vectors as input, aggregate that information to infer the logical relationship.
       This involes summing up both vectors and feed the concatenation of both summarization results into 
       function ℎ (an MLP) to obtain the classification result of the logical relationship.
    """
    def __init__(self, num_inputs, num_hiddens, num_outputs, **kwargs):
        super(Aggregate, self).__init__(**kwargs)
        self.h = mlp(num_inputs, num_hiddens, flatten=True)
        self.linear = nn.Linear(num_hiddens, num_outputs)
    def forward(self, V_A, V_B):
        # Sum up both sets of comparison vectors
        V_A = V_A.sum(dim=1)
        V_B = V_B.sum(dim=1)
        # Feed the concatenation of both summarization results into an MLP
        Y_hat = self.linear(self.h(torch.cat([V_A, V_B], dim=1)))
        return Y_hat

# %%
class DecomposableAttention(nn.Module):
    """Model to jointly train attention, comparing and aggregating steps together."""
    def __init__(self, vocab, embed_size, num_hiddens, num_inputs_attend=100, num_inputs_compare=200, num_inputs_agg=400, **kwargs):
        super(DecomposableAttention, self).__init__(**kwargs)
        self.embedding = nn.Embedding(len(vocab), embed_size)
        self.attend = Attend(num_inputs_attend, num_hiddens)
        self.compare = Compare(num_inputs_compare, num_hiddens)
        # There are 3 possible outputs: entailment, contradiction, and neutral
        self.aggregate = Aggregate(num_inputs_agg, num_hiddens, num_outputs=3)
    def forward(self, X):
        premises, hypotheses = X
        A = self.embedding(premises)
        B = self.embedding(hypotheses)
        beta, alpha = self.attend(A, B)
        V_A, V_B = self.compare(A, B, beta, alpha)
        Y_hat = self.aggregate(V_A, V_B)
        return Y_hat

# %%
# Reading the dataset
batch_size, num_steps = 256, 50
train_iter, test_iter, vocab, data_dir = load_data_snli(batch_size, num_steps)
# Out:
#  ---> snli data already extracted at ../data/snli_1.0
#  ---> read 549367 examples
#  ---> read 9824 examples

# %%
# # create Model
# embed_size, num_hiddens = 100, 200
# net = DecomposableAttention(vocab, embed_size, num_hiddens)
# glove_embedding = TokenEmbedding('glove.6b.100d')
# embeds = glove_embedding[vocab.idx_to_token]
# net.embedding.weight.data.copy_(embeds)

# %%
# # training and evaluating the model
# lr, num_epochs = 0.001, 4
# trainer = torch.optim.Adam(net.parameters(), lr=lr)
# loss = nn.CrossEntropyLoss(reduction="none")
# results = train_and_evaluate(net, train_iter, test_iter, loss, trainer, num_epochs, try_all_gpus())

# %%
# display_results(results, "GloVe.Embeddings")

# %% [markdown]
# #### Natural Language Inference with `MLP(Multi Layer Perceptrons) and BERT(Bidirectional Encoder Representations from Transformers) embeddings`
# ![Solution Overview](images/NaturalLanguageInference.BERT.png)
# ###### The solution will feed pretrained [BERT](BERT.md) embeddings to [MLP](MLP.md)

# %%
# # bert.small
# num_hiddens = 256
# ffn_num_hiddens = 512
# num_heads = 4
# num_blks = 2
# bert.base
num_hiddens = 768
ffn_num_hiddens = 3072
num_heads = 12
num_blks = 12

# %%
def load_pretrained_model(pretrained_model, num_hiddens, ffn_num_hiddens, num_heads, num_blks, dropout, max_len, devices):
    data_dir = download_extract(pretrained_model)
    # Define an empty vocabulary to load the predefined vocabulary
    vocab = Vocab()
    vocab.idx_to_token = json.load(open(os.path.join(data_dir, 'vocab.json')))
    vocab.token_to_idx = {token: idx for idx, token in enumerate(
    vocab.idx_to_token)}
    bert = BERTModel(len(vocab), num_hiddens, ffn_num_hiddens=ffn_num_hiddens, num_heads=num_heads,num_blks=num_blks, dropout=dropout, max_len=max_len)
    # Load pretrained BERT parameters
    bert.load_state_dict(torch.load(os.path.join(data_dir, 'pretrained.params')))
    return bert, vocab

# %%
# load pretrained BERT 
bert_model, vocab = load_pretrained_model('bert.base', num_hiddens=num_hiddens, ffn_num_hiddens=ffn_num_hiddens, num_heads=num_heads, num_blks=num_blks, dropout=0.1, max_len=512, devices=try_all_gpus())

# %%
# Dataset for fine tuning BERT
# Reduce `batch_size` if there is an out of memory error. In the original BERT
# model, `max_len` = 512
batch_size, max_len, num_workers = 512, 128, get_dataloader_workers()
train_set = SNLIBERTDataset(read_snli(data_dir, True), max_len, vocab)
test_set = SNLIBERTDataset(read_snli(data_dir, False), max_len, vocab)
train_iter = torch.utils.data.DataLoader(train_set, batch_size, shuffle=True, num_workers=num_workers)
test_iter = torch.utils.data.DataLoader(test_set, batch_size, num_workers=num_workers)
# Out:
#  ---> read 549367 examples
#  ---> read 9824 examples

# %%
# Fine tuning BERT
bert_net = BERTClassifier(bert_model)

# %%
torch.mps.set_per_process_memory_fraction(0.0)

# %%
# train and evaluate Model performance
lr, num_epochs = 1e-4, 5
trainer = torch.optim.Adam(bert_net.parameters(), lr=lr)
loss = nn.CrossEntropyLoss(reduction='none')
bert_net(next(iter(train_iter))[0])
results = train_and_evaluate(bert_net, train_iter, test_iter, loss, trainer, num_epochs, try_all_gpus())
# Out:
#  ---> started training model ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 6
#       4 loss = nn.CrossEntropyLoss(reduction='none')
#       5 bert_net(next(iter(train_iter))[0])
# ----> 6 results = train_and_evaluate(bert_net, train_iter, test_iter, loss, trainer, num_epochs, try_all_gpus())
#
# File ~/Desktop/AI/Berkeley/projects/Capstone--Final-Report/utilities.ipynb:500, in train_and_evaluate(net, train_iter, test_iter, loss, trainer, num_epochs, devices)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "cbbcb80c-b34e-4df5-a5a2-678261bd2600",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "DATA_HUB = dict()\n",
#      11     "DATA_URL = 'http://d2l-data.s3-accelerate.amazonaws.com/'\n",
#      12     "DATA_HUB['SNLI'] = ('https://nlp.stanford.edu/projects/snli/snli_1.0.zip', '9fcde07509c7e87ec61c640c1b2753d9041758e4')\n",
#      13     "DATA_HUB['glove.6b.50d'] = (DATA_URL + 'glove.6B.50d.zip', '0b8703943ccdb6eb788e6f091b8946e82231bc4d')\n",
#      14     "DATA_HUB['glove.6b.100d'] = (DATA_URL + 'glove.6B.100d.zip', 'cd43bfb07e44e6f27cbcc7bc9ae3d80284fdaf5a')\n",
#      15     "DATA_HUB['glove.42b.300d'] = (DATA_URL + 'glove.42B.300d.zip', 'b5116e234e9eb9076672cfeabf5469f3eec904fa')\n",
#      16     "DATA_HUB['bert.small'] = (DATA_URL + 'bert.small.torch.zip', 'c72329e68a732bef0452e4b96a1c341c8910f81f')\n",
#      17     "DATA_HUB['bert.base'] = (DATA_URL + 'bert.base.torch.zip', '225d66f04cae318b841a13d32af3acc165f253ac')\n",
#      18     "\n",
#      19     "import numpy as np\n",
#      20     "import torch\n",
#      21     "import torchvision\n",
#      22     "from PIL import Image\n",
#      23     "from torch import nn\n",
#      24     "from torch.nn import functional as F\n",
#      25     "from torch.utils import data\n",
#      26     "from torchvision import transforms\n",
#      27     "from pathlib import Path\n",
#      28     "\n",
#      29     "nn_Module = nn.Module\n",
#      30     "\n",
#      31     "import json\n",
#      32     "import multiprocessing\n",
#      33     "import collections\n",
#      34     "import hashlib\n",
#      35     "import inspect\n",
#      36     "import math\n",
#      37     "import os\n",
#      38     "import random\n",
#      39     "import re\n",
#      40     "import shutil\n",
#      41     "import sys\n",
#      42     "import tarfile\n",
#      43     "import time\n",
#      44     "import zipfile\n",
#      45     "from collections import defaultdict\n",
#      46     "import pandas as pd\n",
#      47     "import requests\n",
#      48     "from IPython import display\n",
#      49     "from matplotlib import pyplot as plt\n",
#      50     "import matplotlib.ticker as tkr\n",
#      51     "from matplotlib_inline import backend_inline\n",
#      52     "\n",
#      53     "# nli = sys.modules[__name__]\n",
#      54     "\n",
#      55     "import numpy as np\n",
#      56     "import torch\n",
#      57     "import torchvision\n",
#      58     "from PIL import Image\n",
#      59     "from scipy.spatial import distance_matrix\n",
#      60     "from torch import nn\n",
#      61     "from torch.nn import functional as F\n",
#      62     "from torchvision import transforms"
#      63    ]
#      64   },
#      65   {
#      66    "cell_type": "code",
#      67    "execution_count": 2,
#      68    "id": "9a9d6dbd-2bbf-4072-b778-e4a024240af8",
#      69    "metadata": {},
#      70    "outputs": [],
#      71    "source": [
#      72     "nlinumpy = lambda x, *args, **kwargs: x.detach().numpy(*args, **kwargs)\n",
#      73     "nlito = lambda x, *args, **kwargs: x.to(*args, **kwargs)\n",
#      74     "size = lambda x, *args, **kwargs: x.numel(*args, **kwargs)\n",
#      75     "argmax = lambda x, *args, **kwargs: x.argmax(*args, **kwargs)\n",
#      76     "astype = lambda x, *args, **kwargs: x.type(*args, **kwargs)\n",
#      77     "reduce_sum = lambda x, *args, **kwargs: x.sum(*args, **kwargs)"
#      78    ]
#      79   },
#      80   {
#      81    "cell_type": "code",
#      82    "execution_count": 3,
#      83    "id": "e7c2cc40-35f3-44d1-b315-b3cb01aaec1c",
#      84    "metadata": {},
#      85    "outputs": [],
#      86    "source": [
#      87     "def get_dataloader_workers():\n",
#      88     "    \"\"\"Use 4 processes to read the data.\"\"\"\n",
#      89     "    return 4"
#      90    ]
#      91   },
#      92   {
#      93    "cell_type": "code",
#      94    "execution_count": 4,
#      95    "id": "a7c1e1c8-c986-48d9-9b85-7c1c8d1aa59b",
#      96    "metadata": {},
#      97    "outputs": [],
#      98    "source": [
#      99     "def download(url, folder='../data', sha1_hash=None):\n",
#     100     "    \"\"\"Download a file to folder and return the local filepath.\"\"\"\n",
#     101     "    if not url.startswith('http'):\n",
#     102     "        # For back compatability\n",
#     103     "        url, sha1_hash = DATA_HUB[url]\n",
#     104     "    os.makedirs(folder, exist_ok=True)\n",
#     105     "    fname = os.path.join(folder, url.split('/')[-1])\n",
#     106     "    # Check if hit cache\n",
#     107     "    if os.path.exists(fname) and sha1_hash:\n",
#     108     "        sha1 = hashlib.sha1()\n",
#     109     "        with open(fname, 'rb') as f:\n",
#     110     "            while True:\n",
#     111     "                data = f.read(1048576)\n",
#     112     "                if not data:\n",
#     113     "                    break\n",
#     114     "                sha1.update(data)\n",
#     115     "        if sha1.hexdigest() == sha1_hash:\n",
#     116     "            return fname\n",
#     117     "    r = requests.get(url, stream=True, verify=True)\n",
#     118     "    with open(fname, 'wb') as f:\n",
#     119     "        f.write(r.content)\n",
#     120     "    # Download\n",
#     121     "    print(f' ---> Downloaded {fname} from {url}.')\n",
#     122     "    return fname"
#     123    ]
#     124   },
#     125   {
#     126    "cell_type": "code",
#     127    "execution_count": 5,
#     128    "id": "d6483676-c4c6-449d-8511-a52b92493cab",
#     129    "metadata": {},
#     130    "outputs": [],
#     131    "source": [
#     132     "def extract_snli(fname):\n",
#     133     "    base_dir = os.path.dirname(fname)\n",
#     134     "    target_dir = os.path.join(base_dir, 'snli_1.0')\n",
#     135     "    if os.path.exists(target_dir):\n",
#     136     "        print(f\" ---> snli data already extracted at {target_dir}\")\n",
#     137     "        return\n",
#     138     "    os.makedirs(target_dir,exist_ok=True)\n",
#     139     "    with zipfile.ZipFile(fname, 'r') as input:\n",
#     140     "        for item in input.namelist():\n",
#     141     "            if '__MACOSX' in item:\n",
#     142     "                continue\n",
#     143     "            if '.DS_Store' in item:\n",
#     144     "                continue\n",
#     145     "            file_name = Path(item).name\n",
#     146     "            if 'Icon' in file_name:\n",
#     147     "                continue\n",
#     148     "            source = input.open(item)\n",
#     149     "            target = open(os.path.join(target_dir, file_name), \"wb\")\n",
#     150     "            with source, target:\n",
#     151     "                shutil.copyfileobj(source, target)\n",
#     152     "    print(f\" ---> extracted snli data to {target_dir}\")"
#     153    ]
#     154   },
#     155   {
#     156    "cell_type": "code",
#     157    "execution_count": 6,
#     158    "id": "4578560c-b26b-49bb-8916-73eb6c7db9f1",
#     159    "metadata": {},
#     160    "outputs": [],
#     161    "source": [
#     162     "def download_extract(name, folder=None):\n",
#     163     "    \"\"\"Download and extract a zip/tar file.\"\"\"\n",
#     164     "    \n",
#     165     "    fname = download(name)\n",
#     166     "    base_dir = os.path.dirname(fname)\n",
#     167     "    data_dir, ext = os.path.splitext(fname)\n",
#     168     "    if ext == '.zip':\n",
#     169     "        if 'snli_1.0.zip' in fname:\n",
#     170     "            extract_snli(fname)\n",
#     171     "        else:\n",
#     172     "            fp = zipfile.ZipFile(fname, 'r')\n",
#     173     "            fp.extractall(base_dir)\n",
#     174     "    elif ext in ('.tar', '.gz'):\n",
#     175     "        fp = tarfile.open(fname, 'r')\n",
#     176     "        fp.extractall(base_dir)\n",
#     177     "    else:\n",
#     178     "        assert False, 'Only zip/tar files can be extracted.'\n",
#     179     "    return os.path.join(base_dir, folder) if folder else data_dir"
#     180    ]
#     181   },
#     182   {
#     183    "cell_type": "code",
#     184    "execution_count": 7,
#     185    "id": "19de1583-2d64-48d9-af5b-5b6a98ecf0df",
#     186    "metadata": {},
#     187    "outputs": [],
#     188    "source": [
#     189     "def read_snli(data_dir, is_train):\n",
#     190     "    \"\"\"Read the SNLI dataset into premises, hypotheses, and labels.`\"\"\"\n",
#     191     "    \n",
#     192     "    def extract_text(s):\n",
#     193     "        # Remove information that will not be used by us\n",
#     194     "        s = re.sub('\\\\(', '', s)\n",
#     195     "        s = re.sub('\\\\)', '', s)\n",
#     196     "        # Substitute two or more consecutive whitespace with space\n",
#     197     "        s = re.sub('\\\\s{2,}', ' ', s)\n",
#     198     "        return s.strip()\n",
#     199     "    label_set = {'entailment': 0, 'contradiction': 1, 'neutral': 2}\n",
#     200     "    file_name = os.path.join(data_dir, 'snli_1.0_train.txt'\n",
#     201     "                             if is_train else 'snli_1.0_test.txt')\n",
#     202     "    with open(file_name, 'r') as f:\n",
#     203     "        rows = [row.split('\\t') for row in f.readlines()[1:]]\n",
#     204     "    premises = [extract_text(row[1]) for row in rows if row[0] in label_set]\n",
#     205     "    hypotheses = [extract_text(row[2]) for row in rows if row[0] in label_set]\n",
#     206     "    labels = [label_set[row[0]] for row in rows if row[0] in label_set]\n",
#     207     "    return premises, hypotheses, labels"
#     208    ]
#     209   },
#     210   {
#     211    "cell_type": "code",
#     212    "execution_count": 8,
#     213    "id": "10f34964-7cf3-4730-a684-6bab7299d3ef",
#     214    "metadata": {},
#     215    "outputs": [],
#     216    "source": [
#     217     "def tokenize(lines, token='word'):\n",
#     218     "    \"\"\"Split text lines into word or character tokens.`\"\"\"\n",
#     219     "    \n",
#     220     "    assert token in ('word', 'char'), 'Unknown token type: ' + token\n",
#     221     "    return [line.split() if token == 'word' else list(line) for line in lines]"
#     222    ]
#     223   },
#     224   {
#     225    "cell_type": "code",
#     226    "execution_count": 9,
#     227    "id": "4b60efd5-e2d4-4c0f-832b-b2d6e45b2937",
#     228    "metadata": {},
#     229    "outputs": [],
#     230    "source": [
#     231     "class Vocab:\n",
#     232     "    \"\"\"Vocabulary for text.\"\"\"\n",
#     233     "    def __init__(self, tokens=[], min_freq=0, reserved_tokens=[]):\n",
#     234     "        \"\"\"Defined in :numref:`sec_text-sequence`\"\"\"\n",
#     235     "        # Flatten a 2D list if needed\n",
#     236     "        if tokens and isinstance(tokens[0], list):\n",
#     237     "            tokens = [token for line in tokens for token in line]\n",
#     238     "        # Count token frequencies\n",
#     239     "        counter = collections.Counter(tokens)\n",
#     240     "        self.token_freqs = sorted(counter.items(), key=lambda x: x[1],\n",
#     241     "                                  reverse=True)\n",
#     242     "        # The list of unique tokens\n",
#     243     "        self.idx_to_token = list(sorted(set(['<unk>'] + reserved_tokens + [\n",
#     244     "            token for token, freq in self.token_freqs if freq >= min_freq])))\n",
#     245     "        self.token_to_idx = {token: idx\n",
#     246     "                             for idx, token in enumerate(self.idx_to_token)}\n",
#     247     "\n",
#     248     "    def __len__(self):\n",
#     249     "        return len(self.idx_to_token)\n",
#     250     "\n",
#     251     "    def __getitem__(self, tokens):\n",
#     252     "        if not isinstance(tokens, (list, tuple)):\n",
#     253     "            return self.token_to_idx.get(tokens, self.unk)\n",
#     254     "        return [self.__getitem__(token) for token in tokens]\n",
#     255     "\n",
#     256     "    def to_tokens(self, indices):\n",
#     257     "        if hasattr(indices, '__len__') and len(indices) > 1:\n",
#     258     "            return [self.idx_to_token[int(index)] for index in indices]\n",
#     259     "        return self.idx_to_token[indices]\n",
#     260     "\n",
#     261     "    @property\n",
#     262     "    def unk(self):  # Index for the unknown token\n",
#     263     "        return self.token_to_idx['<unk>']"
#     264    ]
#     265   },
#     266   {
#     267    "cell_type": "code",
#     268    "execution_count": 10,
#     269    "id": "479bc3d9-51a0-421c-b26a-17432275ebb6",
#     270    "metadata": {},
#     271    "outputs": [],
#     272    "source": [
#     273     "def truncate_pad(line, num_steps, padding_token):\n",
#     274     "    \"\"\"Truncate or pad sequences.\n",
#     275     "\n",
#     276     "    Defined in :numref:`sec_utils`\"\"\"\n",
#     277     "    if len(line) > num_steps:\n",
#     278     "        return line[:num_steps]  # Truncate\n",
#     279     "    return line + [padding_token] * (num_steps - len(line))  # Pad"
#     280    ]
#     281   },
#     282   {
#     283    "cell_type": "code",
#     284    "execution_count": 11,
#     285    "id": "ad122cb6-8967-42ff-b87d-c5e708b97824",
#     286    "metadata": {},
#     287    "outputs": [],
#     288    "source": [
#     289     "class SNLIDataset(torch.utils.data.Dataset):\n",
#     290     "    \"\"\"A customized dataset to load the SNLI dataset.\"\"\"\n",
#     291     "    \n",
#     292     "    def __init__(self, dataset, num_steps, vocab=None):\n",
#     293     "        self.num_steps = num_steps\n",
#     294     "        all_premise_tokens = tokenize(dataset[0])\n",
#     295     "        all_hypothesis_tokens = tokenize(dataset[1])\n",
#     296     "        if vocab is None:\n",
#     297     "            self.vocab = Vocab(all_premise_tokens + all_hypothesis_tokens,\n",
#     298     "                                   min_freq=5, reserved_tokens=['<pad>'])\n",
#     299     "        else:\n",
#     300     "            self.vocab = vocab\n",
#     301     "        self.premises = self._pad(all_premise_tokens)\n",
#     302     "        self.hypotheses = self._pad(all_hypothesis_tokens)\n",
#     303     "        self.labels = torch.tensor(dataset[2])\n",
#     304     "        print(' ---> read ' + str(len(self.premises)) + ' examples')\n",
#     305     "\n",
#     306     "    def _pad(self, lines):\n",
#     307     "        return torch.tensor([truncate_pad(\n",
#     308     "            self.vocab[line], self.num_steps, self.vocab['<pad>'])\n",
#     309     "                         for line in lines])\n",
#     310     "\n",
#     311     "    def __getitem__(self, idx):\n",
#     312     "        return (self.premises[idx], self.hypotheses[idx]), self.labels[idx]\n",
#     313     "\n",
#     314     "    def __len__(self):\n",
#     315     "        return len(self.premises)"
#     316    ]
#     317   },
#     318   {
#     319    "cell_type": "code",
#     320    "execution_count": 12,
#     321    "id": "f644c497-a60b-421d-8519-d80951bd5711",
#     322    "metadata": {},
#     323    "outputs": [],
#     324    "source": [
#     325     "def load_data_snli(batch_size, num_steps=50):\n",
#     326     "    \"\"\"Download the SNLI dataset and return data iterators and vocabulary.\"\"\"\n",
#     327     "    num_workers = get_dataloader_workers()\n",
#     328     "    data_dir = download_extract('SNLI')\n",
#     329     "    train_data = read_snli(data_dir, True)\n",
#     330     "    test_data = read_snli(data_dir, False)\n",
#     331     "    train_set = SNLIDataset(train_data, num_steps)\n",
#     332     "    test_set = SNLIDataset(test_data, num_steps, train_set.vocab)\n",
#     333     "    train_iter = torch.utils.data.DataLoader(train_set, batch_size,\n",
#     334     "                                             shuffle=True,\n",
#     335     "                                             num_workers=num_workers)\n",
#     336     "    test_iter = torch.utils.data.DataLoader(test_set, batch_size,\n",
#     337     "                                            shuffle=False,\n",
#     338     "                                            num_workers=num_workers)\n",
#     339     "    return train_iter, test_iter, train_set.vocab, data_dir"
#     340    ]
#     341   },
#     342   {
#     343    "cell_type": "code",
#     344    "execution_count": 13,
#     345    "id": "75811314-6b0a-4710-a5f4-6f54e4556ae3",
#     346    "metadata": {},
#     347    "outputs": [],
#     348    "source": [
#     349     "def cpu():\n",
#     350     "    \"\"\"Get the CPU device.\"\"\"\n",
#     351     "    return torch.device('cpu')\n",
#     352     "    \n",
#     353     "def gpu(i=0, gpu_type=None):\n",
#     354     "    \"\"\"Get a GPU device.\"\"\"\n",
#     355     "    if not gpu_type or gpu_type == \"cuda\":\n",
#     356     "        return torch.device(f'cuda:{i}')\n",
#     357     "    else:\n",
#     358     "        return torch.device(f'mps:{i}')\n",
#     359     "\n",
#     360     "def num_gpus():\n",
#     361     "    \"\"\"Get the number of available GPUs.\"\"\"\n",
#     362     "    if torch.cuda.is_available():\n",
#     363     "        return \"cuda\", torch.cuda.device_count()\n",
#     364     "    elif torch.mps.is_available():\n",
#     365     "        return \"mps\", torch.mps.device_count()\n",
#     366     "    else:\n",
#     367     "        return None, 0\n",
#     368     "\n",
#     369     "def try_gpu(i=0):\n",
#     370     "    \"\"\"Return gpu(i) if exists, otherwise return cpu().\n",
#     371     "\n",
#     372     "    Defined in :numref:`sec_use_gpu`\"\"\"\n",
#     373     "    gpu_type, count = num_gpus()\n",
#     374     "    if count >= i + 1:\n",
#     375     "        return gpu(i, gpu_type)\n",
#     376     "    return cpu()\n",
#     377     "\n",
#     378     "def try_all_gpus():\n",
#     379     "    \"\"\"Return all available GPUs, or [cpu(),] if no GPU exists.\n",
#     380     "\n",
#     381     "    Defined in :numref:`sec_use_gpu`\"\"\"\n",
#     382     "    gpu_type, count = num_gpus()\n",
#     383     "    return [gpu(i, gpu_type) for i in range(count)]\n"
#     384    ]
#     385   },
#     386   {
#     387    "cell_type": "code",
#     388    "execution_count": 14,
#     389    "id": "21aa794d-add2-40aa-a11d-a9b58a0c3bd0",
#     390    "metadata": {},
#     391    "outputs": [],
#     392    "source": [
#     393     "class TokenEmbedding:\n",
#     394     "    \"\"\"Token Embedding.\"\"\"\n",
#     395     "    def __init__(self, embedding_name):\n",
#     396     "        \"\"\"Defined in :numref:`sec_synonyms`\"\"\"\n",
#     397     "        self.idx_to_token, self.idx_to_vec = self._load_embedding(\n",
#     398     "            embedding_name)\n",
#     399     "        self.unknown_idx = 0\n",
#     400     "        self.token_to_idx = {token: idx for idx, token in\n",
#     401     "                             enumerate(self.idx_to_token)}\n",
#     402     "\n",
#     403     "    def _load_embedding(self, embedding_name):\n",
#     404     "        idx_to_token, idx_to_vec = ['<unk>'], []\n",
#     405     "        data_dir = download_extract(embedding_name)\n",
#     406     "        # GloVe website: https://nlp.stanford.edu/projects/glove/\n",
#     407     "        # fastText website: https://fasttext.cc/\n",
#     408     "        with open(os.path.join(data_dir, 'vec.txt'), 'r', encoding='cp437') as f:\n",
#     409     "            for line in f:\n",
#     410     "                elems = line.rstrip().split(' ')\n",
#     411     "                token, elems = elems[0], [float(elem) for elem in elems[1:]]\n",
#     412     "                # Skip header information, such as the top row in fastText\n",
#     413     "                if len(elems) > 1:\n",
#     414     "                    idx_to_token.append(token)\n",
#     415     "                    idx_to_vec.append(elems)\n",
#     416     "        idx_to_vec = [[0] * len(idx_to_vec[0])] + idx_to_vec\n",
#     417     "        return idx_to_token, torch.tensor(idx_to_vec)\n",
#     418     "\n",
#     419     "    def __getitem__(self, tokens):\n",
#     420     "        indices = [self.token_to_idx.get(token, self.unknown_idx)\n",
#     421     "                   for token in tokens]\n",
#     422     "        vecs = self.idx_to_vec[torch.tensor(indices)]\n",
#     423     "        return vecs\n",
#     424     "\n",
#     425     "    def __len__(self):\n",
#     426     "        return len(self.idx_to_token)"
#     427    ]
#     428   },
#     429   {
#     430    "cell_type": "code",
#     431    "execution_count": 15,
#     432    "id": "2c717e05-3894-4269-8131-9a171442e638",
#     433    "metadata": {},
#     434    "outputs": [],
#     435    "source": [
#     436     "class Timer:\n",
#     437     "    \"\"\"Record multiple running times.\"\"\"\n",
#     438     "    def __init__(self):\n",
#     439     "        \"\"\"Defined in :numref:`sec_minibatch_sgd`\"\"\"\n",
#     440     "        self.times = []\n",
#     441     "        self.start()\n",
#     442     "\n",
#     443     "    def start(self):\n",
#     444     "        \"\"\"Start the timer.\"\"\"\n",
#     445     "        self.tik = time.time()\n",
#     446     "\n",
#     447     "    def stop(self):\n",
#     448     "        \"\"\"Stop the timer and record the time in a list.\"\"\"\n",
#     449     "        self.times.append(time.time() - self.tik)\n",
#     450     "        return self.times[-1]\n",
#     451     "\n",
#     452     "    def avg(self):\n",
#     453     "        \"\"\"Return the average time.\"\"\"\n",
#     454     "        return sum(self.times) / len(self.times)\n",
#     455     "\n",
#     456     "    def sum(self):\n",
#     457     "        \"\"\"Return the sum of time.\"\"\"\n",
#     458     "        return sum(self.times)\n",
#     459     "\n",
#     460     "    def cumsum(self):\n",
#     461     "        \"\"\"Return the accumulated time.\"\"\"\n",
#     462     "        return np.array(self.times).cumsum().tolist()\n"
#     463    ]
#     464   },
#     465   {
#     466    "cell_type": "code",
#     467    "execution_count": 16,
#     468    "id": "4512b8a6-baea-47c8-b3d6-b635d17c2231",
#     469    "metadata": {},
#     470    "outputs": [],
#     471    "source": [
#     472     "def use_svg_display():\n",
#     473     "    \"\"\"Use the svg format to display a plot in Jupyter.\n",
#     474     "\n",
#     475     "    Defined in :numref:`sec_calculus`\"\"\"\n",
#     476     "    backend_inline.set_matplotlib_formats('svg')\n",
#     477     "\n",
#     478     "def set_figsize(figsize=(3.5, 2.5)):\n",
#     479     "    \"\"\"Set the figure size for matplotlib.\n",
#     480     "\n",
#     481     "    Defined in :numref:`sec_calculus`\"\"\"\n",
#     482     "    use_svg_display()\n",
#     483     "    plt.rcParams['figure.figsize'] = figsize\n",
#     484     "\n",
#     485     "def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):\n",
#     486     "    \"\"\"Set the axes for matplotlib.\n",
#     487     "\n",
#     488     "    Defined in :numref:`sec_calculus`\"\"\"\n",
#     489     "    axes.set_xlabel(xlabel), axes.set_ylabel(ylabel)\n",
#     490     "    axes.set_xscale(xscale), axes.set_yscale(yscale)\n",
#     491     "    axes.set_xlim(xlim),     axes.set_ylim(ylim)\n",
#     492     "    if legend:\n",
#     493     "        axes.legend(legend)\n",
#     494     "    axes.grid()\n"
#     495    ]
#     496   },
#     497   {
#     498    "cell_type": "code",
#     499    "execution_count": 17,
# --> 500    "id": "73565fb9-36a2-4880-8bf3-b65e4daca331",
#     501    "metadata": {},
#     502    "outputs": [],
#     503    "source": [
#     504     "class Animator:\n",
#     505     "    \"\"\"For plotting data in animation.\"\"\"\n",
#     506     "    def __init__(self, xlabel=None, ylabel=None, legend=None, xlim=None,\n",
#     507     "                 ylim=None, xscale='linear', yscale='linear',\n",
#     508     "                 fmts=('-', 'm--', 'g-.', 'r:'), nrows=1, ncols=1,\n",
#     509     "                 figsize=(3.5, 2.5)):\n",
#     510     "        \"\"\"Defined in :numref:`sec_utils`\"\"\"\n",
#     511     "        # Incrementally plot multiple lines\n",
#     512     "        if legend is None:\n",
#     513     "            legend = []\n",
#     514     "        use_svg_display()\n",
#     515     "        self.fig, self.axes = plt.subplots(nrows, ncols, figsize=figsize)\n",
#     516     "        if nrows * ncols == 1:\n",
#     517     "            self.axes = [self.axes, ]\n",
#     518     "        # Use a lambda function to capture arguments\n",
#     519     "        self.config_axes = lambda: set_axes(\n",
#     520     "            self.axes[0], xlabel, ylabel, xlim, ylim, xscale, yscale, legend)\n",
#     521     "        self.X, self.Y, self.fmts = None, None, fmts\n",
#     522     "\n",
#     523     "    def add(self, x, y):\n",
#     524     "        # Add multiple data points into the figure\n",
#     525     "        if not hasattr(y, \"__len__\"):\n",
#     526     "            y = [y]\n",
#     527     "        n = len(y)\n",
#     528     "        if not hasattr(x, \"__len__\"):\n",
#     529     "            x = [x] * n\n",
#     530     "        if not self.X:\n",
#     531     "            self.X = [[] for _ in range(n)]\n",
#     532     "        if not self.Y:\n",
#     533     "            self.Y = [[] for _ in range(n)]\n",
#     534     "        for i, (a, b) in enumerate(zip(x, y)):\n",
#     535     "            if a is not None and b is not None:\n",
#     536     "                self.X[i].append(a)\n",
#     537     "                self.Y[i].append(b)\n",
#     538     "        self.axes[0].cla()\n",
#     539     "        for x, y, fmt in zip(self.X, self.Y, self.fmts):\n",
#     540     "            self.axes[0].plot(x, y, fmt)\n",
#     541     "        self.config_axes()\n",
#     542     "        display.display(self.fig)\n",
#     543     "        display.clear_output(wait=True)"
#     544    ]
#     545   },
#     546   {
#     547    "cell_type": "code",
#     548    "execution_count": 18,
#     549    "id": "79903a62-f400-4a9e-8eb7-f3027f15e388",
#     550    "metadata": {},
#     551    "outputs": [],
#     552    "source": [
#     553     "class Accumulator:\n",
#     554     "    \"\"\"For accumulating sums over `n` variables.\"\"\"\n",
#     555     "    def __init__(self, n):\n",
#     556     "        \"\"\"Defined in :numref:`sec_utils`\"\"\"\n",
#     557     "        self.data = [0.0] * n\n",
#     558     "\n",
#     559     "    def add(self, *args):\n",
#     560     "        self.data = [a + float(b) for a, b in zip(self.data, args)]\n",
#     561     "\n",
#     562     "    def reset(self):\n",
#     563     "        self.data = [0.0] * len(self.data)\n",
#     564     "\n",
#     565     "    def __getitem__(self, idx):\n",
#     566     "        return self.data[idx]\n"
#     567    ]
#     568   },
#     569   {
#     570    "cell_type": "code",
#     571    "execution_count": 19,
#     572    "id": "5b425480-928d-4ee5-a4f3-64fd6676cd12",
#     573    "metadata": {},
#     574    "outputs": [],
#     575    "source": [
#     576     "def accuracy(y_hat, y):\n",
#     577     "    \"\"\"Compute the number of correct predictions.\n",
#     578     "\n",
#     579     "    Defined in :numref:`sec_utils`\"\"\"\n",
#     580     "    if len(y_hat.shape) > 1 and y_hat.shape[1] > 1:\n",
#     581     "        y_hat = argmax(y_hat, axis=1)\n",
#     582     "    cmp = astype(y_hat, y.dtype) == y\n",
#     583     "    return float(reduce_sum(astype(cmp, y.dtype)))"
#     584    ]
#     585   },
#     586   {
#     587    "cell_type": "code",
#     588    "execution_count": 20,
#     589    "id": "84a05e6a-3d28-4050-8e5e-e6bbdd79eeb8",
#     590    "metadata": {},
#     591    "outputs": [],
#     592    "source": [
#     593     "def train_in_batch(net, X, y, loss, trainer, devices):\n",
#     594     "    \"\"\"Train for a minibatch with multiple GPUs (defined in Chapter 13).\n",
#     595     "\n",
#     596     "    Defined in :numref:`sec_image_augmentation`\"\"\"\n",
#     597     "    if isinstance(X, list):\n",
#     598     "        # Required for BERT fine-tuning (to be covered later)\n",
#     599     "        X = [x.to(devices[0]) for x in X]\n",
#     600     "    else:\n",
#     601     "        X = X.to(devices[0])\n",
#     602     "    y = y.to(devices[0])\n",
#     603     "    net.train()\n",
#     604     "    trainer.zero_grad()\n",
#     605     "    pred = net(X)\n",
#     606     "    l = loss(pred, y)\n",
#     607     "    l.sum().backward()\n",
#     608     "    trainer.step()\n",
#     609     "    train_loss_sum = l.sum()\n",
#     610     "    train_acc_sum = accuracy(pred, y)\n",
#     611     "    return train_loss_sum, train_acc_sum"
#     612    ]
#     613   },
#     614   {
#     615    "cell_type": "code",
#     616    "execution_count": null,
#     617    "id": "3f2d2b47-7e4c-49b6-8145-9c62fb895e57",
#     618    "metadata": {},
#     619    "outputs": [],
#     620    "source": []
#     621   },
#     622   {
#     623    "cell_type": "code",
#     624    "execution_count": 21,
#     625    "id": "861948e6-a046-4262-87bf-b31eacfd5d2f",
#     626    "metadata": {},
#     627    "outputs": [],
#     628    "source": [
#     629     "def evaluate_accuracy_gpu_for_snli(net, data_iter, device=None):\n",
#     630     "    \"\"\"Compute the accuracy for a model on a dataset using a GPU.\"\"\"\n",
#     631     "    if isinstance(net, nn.Module):\n",
#     632     "        net.eval()  # Set the model to evaluation mode\n",
#     633     "        if not device:\n",
#     634     "            device = next(iter(net.parameters())).device\n",
#     635     "    # No. of correct predictions, no. of predictions\n",
#     636     "    metric = Accumulator(2)\n",
#     637     "\n",
#     638     "    with torch.no_grad():\n",
#     639     "        for X, y in data_iter:\n",
#     640     "            if isinstance(X, list):\n",
#     641     "                # Required for BERT Fine-tuning (to be covered later)\n",
#     642     "                X = [x.to(device) for x in X]\n",
#     643     "            else:\n",
#     644     "                X = X.to(device)\n",
#     645     "            y = y.to(device)           \n",
#     646     "            metric.add(accuracy(net(X), y), size(y))\n",
#     647     "            \n",
#     648     "    # test_accuracy, no. of predictions, No. of correct predictions, no. of wrong predictions\n",
#     649     "    return (metric[0] / metric[1], metric[1], metric[0], metric[1] - metric[0]) "
#     650    ]
#     651   },
#     652   {
#     653    "cell_type": "code",
#     654    "execution_count": 22,
#     655    "id": "d40c5465-a5c1-416e-87fa-36025b12c63e",
#     656    "metadata": {},
#     657    "outputs": [],
#     658    "source": [
#     659     "def train_and_evaluate(net, train_iter, test_iter, loss, trainer, num_epochs,\n",
#     660     "               devices=try_all_gpus()):\n",
#     661     "    \"\"\"Train a model with multiple GPUs.\"\"\"\n",
#     662     "    \n",
#     663     "    print(\" ---> started training model ... \")\n",
#     664     "    timer, num_batches = Timer(), len(train_iter)\n",
#     665     "    animator = Animator(xlabel='epoch', xlim=[1, num_epochs], ylim=[0, 1],\n",
#     666     "                            legend=['train loss', 'train accuracy', 'test acccuracy'])\n",
#     667     "    net = nn.DataParallel(net, device_ids=devices).to(devices[0])\n",
#     668     "    for epoch in range(num_epochs):\n",
#     669     "        # Sum of training loss, sum of training accuracy, no. of examples,\n",
#     670     "        # no. of predictions\n",
#     671     "        metric = Accumulator(4)\n",
#     672     "        for i, (features, labels) in enumerate(train_iter):\n",
#     673     "            timer.start()\n",
#     674     "            l, acc = train_in_batch(\n",
#     675     "                net, features, labels, loss, trainer, devices)\n",
#     676     "            metric.add(l, acc, labels.shape[0], labels.numel())\n",
#     677     "            timer.stop()\n",
#     678     "            if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:\n",
#     679     "                animator.add(epoch + (i + 1) / num_batches,\n",
#     680     "                             (metric[0] / metric[2], metric[1] / metric[3],\n",
#     681     "                              None))\n",
#     682     "        test_acc, test_num_of_examples, test_passed, test_failed = evaluate_accuracy_gpu_for_snli(net, test_iter)\n",
#     683     "        animator.add(epoch + 1, (None, None, test_acc))\n",
#     684     "        \n",
#     685     "    test_loss = 1 - test_acc\n",
#     686     "    training, test, results = dict(), dict(), dict()\n",
#     687     "    training['total_examples'], test['total_examples'] = metric[2] , test_num_of_examples\n",
#     688     "    training['passed'], test['passed'] = metric[1], test_passed\n",
#     689     "    training['failed'], test['failed'] = metric[2] - metric[1], test_failed\n",
#     690     "    training['accuracy'], test['accuracy'] = int((metric[1] * 100) / metric[3]), int(test_acc * 100)\n",
#     691     "    training['loss'], test['loss'] = f'{metric[0] / metric[2]:.3f}', f'{test_loss:.3f}'\n",
#     692     "    results['training'] = training\n",
#     693     "    results['test'] = test\n",
#     694     "    print(results)\n",
#     695     "    return results\n",
#     696     "    "
#     697    ]
#     698   },
#     699   {
#     700    "cell_type": "code",
#     701    "execution_count": 23,
#     702    "id": "777e7c73-dd91-4134-962e-23e3e252113b",
#     703    "metadata": {},
#     704    "outputs": [],
#     705    "source": [
#     706     "class MaskLM(nn.Module):\n",
#     707     "    \"\"\"The masked language model task of BERT.`\"\"\"\n",
#     708     "    def __init__(self, vocab_size, num_hiddens, **kwargs):\n",
#     709     "        super(MaskLM, self).__init__(**kwargs)\n",
#     710     "        self.mlp = nn.Sequential(nn.LazyLinear(num_hiddens),\n",
#     711     "                                 nn.ReLU(),\n",
#     712     "                                 nn.LayerNorm(num_hiddens),\n",
#     713     "                                 nn.LazyLinear(vocab_size))\n",
#     714     "\n",
#     715     "    def forward(self, X, pred_positions):\n",
#     716     "        num_pred_positions = pred_positions.shape[1]\n",
#     717     "        pred_positions = pred_positions.reshape(-1)\n",
#     718     "        batch_size = X.shape[0]\n",
#     719     "        batch_idx = torch.arange(0, batch_size)\n",
#     720     "        # Suppose that `batch_size` = 2, `num_pred_positions` = 3, then\n",
#     721     "        # `batch_idx` is `torch.tensor([0, 0, 0, 1, 1, 1])`\n",
#     722     "        batch_idx = torch.repeat_interleave(batch_idx, num_pred_positions)\n",
#     723     "        masked_X = X[batch_idx, pred_positions]\n",
#     724     "        masked_X = masked_X.reshape((batch_size, num_pred_positions, -1))\n",
#     725     "        mlm_Y_hat = self.mlp(masked_X)\n",
#     726     "        return mlm_Y_hat"
#     727    ]
#     728   },
#     729   {
#     730    "cell_type": "code",
#     731    "execution_count": null,
#     732    "id": "67ea9c4a-aed5-4f69-a3ea-c9e6aec27be2",
#     733    "metadata": {},
#     734    "outputs": [],
#     735    "source": []
#     736   },
#     737   {
#     738    "cell_type": "code",
#     739    "execution_count": 24,
#     740    "id": "d5980dc8-f390-4f92-96dc-75efc51c6e17",
#     741    "metadata": {},
#     742    "outputs": [],
#     743    "source": [
#     744     "def masked_softmax(X, valid_lens):\n",
#     745     "    \"\"\"Perform softmax operation by masking elements on the last axis.\"\"\"\n",
#     746     "    # X: 3D tensor, valid_lens: 1D or 2D tensor\n",
#     747     "    def _sequence_mask(X, valid_len, value=0):\n",
#     748     "        maxlen = X.size(1)\n",
#     749     "        mask = torch.arange((maxlen), dtype=torch.float32,\n",
#     750     "                            device=X.device)[None, :] < valid_len[:, None]\n",
#     751     "        X[~mask] = value\n",
#     752     "        return X\n",
#     753     "\n",
#     754     "    if valid_lens is None:\n",
#     755     "        return nn.functional.softmax(X, dim=-1)\n",
#     756     "    else:\n",
#     757     "        shape = X.shape\n",
#     758     "        if valid_lens.dim() == 1:\n",
#     759     "            valid_lens = torch.repeat_interleave(valid_lens, shape[1])\n",
#     760     "        else:\n",
#     761     "            valid_lens = valid_lens.reshape(-1)\n",
#     762     "        # On the last axis, replace masked elements with a very large negative\n",
#     763     "        # value, whose exponentiation outputs 0\n",
#     764     "        X = _sequence_mask(X.reshape(-1, shape[-1]), valid_lens, value=-1e6)\n",
#     765     "        return nn.functional.softmax(X.reshape(shape), dim=-1)\n"
#     766    ]
#     767   },
#     768   {
#     769    "cell_type": "code",
#     770    "execution_count": 25,
#     771    "id": "72eda387-7bc9-485c-ba4a-6f9303660523",
#     772    "metadata": {},
#     773    "outputs": [],
#     774    "source": [
#     775     "class DotProductAttention(nn.Module):\n",
#     776     "    \"\"\"Scaled dot product attention.\"\"\"\n",
#     777     "    def __init__(self, dropout):\n",
#     778     "        super().__init__()\n",
#     779     "        self.dropout = nn.Dropout(dropout)\n",
#     780     "\n",
#     781     "    # Shape of queries: (batch_size, no. of queries, d)\n",
#     782     "    # Shape of keys: (batch_size, no. of key-value pairs, d)\n",
#     783     "    # Shape of values: (batch_size, no. of key-value pairs, value dimension)\n",
#     784     "    # Shape of valid_lens: (batch_size,) or (batch_size, no. of queries)\n",
#     785     "    def forward(self, queries, keys, values, valid_lens=None):\n",
#     786     "        d = queries.shape[-1]\n",
#     787     "        # Swap the last two dimensions of keys with keys.transpose(1, 2)\n",
#     788     "        scores = torch.bmm(queries, keys.transpose(1, 2)) / math.sqrt(d)\n",
#     789     "        self.attention_weights = masked_softmax(scores, valid_lens)\n",
#     790     "        return torch.bmm(self.dropout(self.attention_weights), values)"
#     791    ]
#     792   },
#     793   {
#     794    "cell_type": "code",
#     795    "execution_count": 26,
#     796    "id": "2a1d2637-35ba-448f-9c8f-7fec1be1a169",
#     797    "metadata": {},
#     798    "outputs": [],
#     799    "source": [
#     800     "class NLIHyperParameters:\n",
#     801     "    \"\"\"The base class of hyperparameters.\"\"\"\n",
#     802     "    def save_hyperparameters(self, ignore=[]):\n",
#     803     "        \"\"\"Defined in :numref:`sec_oo-design`\"\"\"\n",
#     804     "        raise NotImplemented\n",
#     805     "\n",
#     806     "    def save_hyperparameters(self, ignore=[]):\n",
#     807     "        \"\"\"Save function arguments into class attributes.\n",
#     808     "    \n",
#     809     "        Defined in :numref:`sec_utils`\"\"\"\n",
#     810     "        frame = inspect.currentframe().f_back\n",
#     811     "        _, _, _, local_vars = inspect.getargvalues(frame)\n",
#     812     "        self.hparams = {k:v for k, v in local_vars.items()\n",
#     813     "                        if k not in set(ignore+['self']) and not k.startswith('_')}\n",
#     814     "        for k, v in self.hparams.items():\n",
#     815     "            setattr(self, k, v)"
#     816    ]
#     817   },
#     818   {
#     819    "cell_type": "code",
#     820    "execution_count": 27,
#     821    "id": "8dec1ae0-8dc6-4cb2-89a1-a794b8c8d77b",
#     822    "metadata": {},
#     823    "outputs": [],
#     824    "source": [
#     825     "class ProgressBoard(NLIHyperParameters):\n",
#     826     "    \"\"\"The board that plots data points in animation\"\"\"\n",
#     827     "    def __init__(self, xlabel=None, ylabel=None, xlim=None,\n",
#     828     "                 ylim=None, xscale='linear', yscale='linear',\n",
#     829     "                 ls=['-', '--', '-.', ':'], colors=['C0', 'C1', 'C2', 'C3'],\n",
#     830     "                 fig=None, axes=None, figsize=(3.5, 2.5), display=True):\n",
#     831     "        self.save_hyperparameters()\n",
#     832     "\n",
#     833     "    def draw(self, x, y, label, every_n=1):\n",
#     834     "        raise NotImplemented\n",
#     835     "\n",
#     836     "    def draw(self, x, y, label, every_n=1):\n",
#     837     "        \"\"\"Defined in :numref:`sec_utils`\"\"\"\n",
#     838     "        Point = collections.namedtuple('Point', ['x', 'y'])\n",
#     839     "        if not hasattr(self, 'raw_points'):\n",
#     840     "            self.raw_points = collections.OrderedDict()\n",
#     841     "            self.data = collections.OrderedDict()\n",
#     842     "        if label not in self.raw_points:\n",
#     843     "            self.raw_points[label] = []\n",
#     844     "            self.data[label] = []\n",
#     845     "        points = self.raw_points[label]\n",
#     846     "        line = self.data[label]\n",
#     847     "        points.append(Point(x, y))\n",
#     848     "        if len(points) != every_n:\n",
#     849     "            return\n",
#     850     "        mean = lambda x: sum(x) / len(x)\n",
#     851     "        line.append(Point(mean([p.x for p in points]),\n",
#     852     "                          mean([p.y for p in points])))\n",
#     853     "        points.clear()\n",
#     854     "        if not self.display:\n",
#     855     "            return\n",
#     856     "        use_svg_display()\n",
#     857     "        if self.fig is None:\n",
#     858     "            self.fig = plt.figure(figsize=self.figsize)\n",
#     859     "        plt_lines, labels = [], []\n",
#     860     "        for (k, v), ls, color in zip(self.data.items(), self.ls, self.colors):\n",
#     861     "            plt_lines.append(plt.plot([p.x for p in v], [p.y for p in v],\n",
#     862     "                                          linestyle=ls, color=color)[0])\n",
#     863     "            labels.append(k)\n",
#     864     "        axes = self.axes if self.axes else plt.gca()\n",
#     865     "        if self.xlim: axes.set_xlim(self.xlim)\n",
#     866     "        if self.ylim: axes.set_ylim(self.ylim)\n",
#     867     "        if not self.xlabel: self.xlabel = self.x\n",
#     868     "        axes.set_xlabel(self.xlabel)\n",
#     869     "        axes.set_ylabel(self.ylabel)\n",
#     870     "        axes.set_xscale(self.xscale)\n",
#     871     "        axes.set_yscale(self.yscale)\n",
#     872     "        axes.legend(plt_lines, labels)\n",
#     873     "        display.display(self.fig)\n",
#     874     "        display.clear_output(wait=True)"
#     875    ]
#     876   },
#     877   {
#     878    "cell_type": "code",
#     879    "execution_count": 28,
#     880    "id": "bc9f3e26-4e76-40a0-a86f-458e01c7960e",
#     881    "metadata": {},
#     882    "outputs": [],
#     883    "source": [
#     884     "class NLIModule(nn.Module, NLIHyperParameters):\n",
#     885     "    \"\"\"The base class of models\"\"\"\n",
#     886     "    def __init__(self, plot_train_per_epoch=2, plot_valid_per_epoch=1):\n",
#     887     "        super().__init__()\n",
#     888     "        self.save_hyperparameters()\n",
#     889     "        self.board = ProgressBoard()\n",
#     890     "\n",
#     891     "    def loss(self, y_hat, y):\n",
#     892     "        raise NotImplementedError\n",
#     893     "\n",
#     894     "    def forward(self, X):\n",
#     895     "        assert hasattr(self, 'net'), 'Neural network is defined'\n",
#     896     "        return self.net(X)\n",
#     897     "\n",
#     898     "    def plot(self, key, value, train):\n",
#     899     "        \"\"\"Plot a point in animation.\"\"\"\n",
#     900     "        assert hasattr(self, 'trainer'), 'Trainer is not inited'\n",
#     901     "        self.board.xlabel = 'epoch'\n",
#     902     "        if train:\n",
#     903     "            x = self.trainer.train_batch_idx / \\\n",
#     904     "                self.trainer.num_train_batches\n",
#     905     "            n = self.trainer.num_train_batches / \\\n",
#     906     "                self.plot_train_per_epoch\n",
#     907     "        else:\n",
#     908     "            x = self.trainer.epoch + 1\n",
#     909     "            n = self.trainer.num_val_batches / \\\n",
#     910     "                self.plot_valid_per_epoch\n",
#     911     "        self.board.draw(x, nlinumpy(nlito(value, cpu())),\n",
#     912     "                        ('train_' if train else 'val_') + key,\n",
#     913     "                        every_n=int(n))\n",
#     914     "\n",
#     915     "    def training_step(self, batch):\n",
#     916     "        l = self.loss(self(*batch[:-1]), batch[-1])\n",
#     917     "        self.plot('loss', l, train=True)\n",
#     918     "        return l\n",
#     919     "\n",
#     920     "    def validation_step(self, batch):\n",
#     921     "        l = self.loss(self(*batch[:-1]), batch[-1])\n",
#     922     "        self.plot('loss', l, train=False)\n",
#     923     "\n",
#     924     "    def configure_optimizers(self):\n",
#     925     "        raise NotImplementedError\n",
#     926     "\n",
#     927     "    def configure_optimizers(self):\n",
#     928     "        \"\"\"Defined in :numref:`sec_classification`\"\"\"\n",
#     929     "        return torch.optim.SGD(self.parameters(), lr=self.lr)\n",
#     930     "\n",
#     931     "    def apply_init(self, inputs, init=None):\n",
#     932     "        \"\"\"Defined in :numref:`sec_lazy_init`\"\"\"\n",
#     933     "        self.forward(*inputs)\n",
#     934     "        if init is not None:\n",
#     935     "            self.net.apply(init)"
#     936    ]
#     937   },
#     938   {
#     939    "cell_type": "code",
#     940    "execution_count": 29,
#     941    "id": "e93e93e1-ee54-4f16-a270-0ee25fd4a87b",
#     942    "metadata": {},
#     943    "outputs": [],
#     944    "source": [
#     945     "class MultiHeadAttention(NLIModule):\n",
#     946     "    \"\"\"Multi-head attention.\"\"\"\n",
#     947     "    def __init__(self, num_hiddens, num_heads, dropout, bias=False, **kwargs):\n",
#     948     "        super().__init__()\n",
#     949     "        self.num_heads = num_heads\n",
#     950     "        self.attention = DotProductAttention(dropout)\n",
#     951     "        self.W_q = nn.LazyLinear(num_hiddens, bias=bias)\n",
#     952     "        self.W_k = nn.LazyLinear(num_hiddens, bias=bias)\n",
#     953     "        self.W_v = nn.LazyLinear(num_hiddens, bias=bias)\n",
#     954     "        self.W_o = nn.LazyLinear(num_hiddens, bias=bias)\n",
#     955     "\n",
#     956     "    def forward(self, queries, keys, values, valid_lens):\n",
#     957     "        # Shape of queries, keys, or values:\n",
#     958     "        # (batch_size, no. of queries or key-value pairs, num_hiddens)\n",
#     959     "        # Shape of valid_lens: (batch_size,) or (batch_size, no. of queries)\n",
#     960     "        # After transposing, shape of output queries, keys, or values:\n",
#     961     "        # (batch_size * num_heads, no. of queries or key-value pairs,\n",
#     962     "        # num_hiddens / num_heads)\n",
#     963     "        queries = self.transpose_qkv(self.W_q(queries))\n",
#     964     "        keys = self.transpose_qkv(self.W_k(keys))\n",
#     965     "        values = self.transpose_qkv(self.W_v(values))\n",
#     966     "\n",
#     967     "        if valid_lens is not None:\n",
#     968     "            # On axis 0, copy the first item (scalar or vector) for num_heads\n",
#     969     "            # times, then copy the next item, and so on\n",
#     970     "            valid_lens = torch.repeat_interleave(\n",
#     971     "                valid_lens, repeats=self.num_heads, dim=0)\n",
#     972     "\n",
#     973     "        # Shape of output: (batch_size * num_heads, no. of queries,\n",
#     974     "        # num_hiddens / num_heads)\n",
#     975     "        output = self.attention(queries, keys, values, valid_lens)\n",
#     976     "        # Shape of output_concat: (batch_size, no. of queries, num_hiddens)\n",
# ...
#    1096     "        # In BERT, positional embeddings are learnable, thus we create a\n",
#    1097     "        # parameter of positional embeddings that are long enough\n",
#    1098     "        self.pos_embedding = nn.Parameter(torch.randn(1, max_len,\n",
#    1099     "                                                      num_hiddens))\n",
#    1100     "\n",
#    1101     "    def forward(self, tokens, segments, valid_lens):\n",
#    1102     "        # Shape of `X` remains unchanged in the following code snippet:\n",
#    1103     "        # (batch size, max sequence length, `num_hiddens`)\n",
#    1104     "        X = self.token_embedding(tokens) + self.segment_embedding(segments)\n",
#    1105     "        X = X + self.pos_embedding[:, :X.shape[1], :]\n",
#    1106     "        for blk in self.blks:\n",
#    1107     "            X = blk(X, valid_lens)\n",
#    1108     "        return X"
#    1109    ]
#    1110   },
#    1111   {
#    1112    "cell_type": "code",
#    1113    "execution_count": 35,
#    1114    "id": "83138d57-76e0-4b0a-8c86-7b2033735e12",
#    1115    "metadata": {},
#    1116    "outputs": [],
#    1117    "source": [
#    1118     "class NextSentencePred(nn.Module):\n",
#    1119     "    \"\"\"The next sentence prediction task of BERT.\"\"\"\n",
#    1120     "    def __init__(self, **kwargs):\n",
#    1121     "        super(NextSentencePred, self).__init__(**kwargs)\n",
#    1122     "        self.output = nn.LazyLinear(2)\n",
#    1123     "\n",
#    1124     "    def forward(self, X):\n",
#    1125     "        # `X` shape: (batch size, `num_hiddens`)\n",
#    1126     "        return self.output(X)"
#    1127    ]
#    1128   },
#    1129   {
#    1130    "cell_type": "code",
#    1131    "execution_count": 36,
#    1132    "id": "5bd70367-95ef-47e3-bd77-9a448686dd88",
#    1133    "metadata": {},
#    1134    "outputs": [],
#    1135    "source": [
#    1136     "class BERTModel(nn.Module):\n",
#    1137     "    \"\"\"The BERT model.\"\"\"\n",
#    1138     "    def __init__(self, vocab_size, num_hiddens, ffn_num_hiddens,\n",
#    1139     "                 num_heads, num_blks, dropout, max_len=1000):\n",
#    1140     "        super(BERTModel, self).__init__()\n",
#    1141     "        self.encoder = BERTEncoder(vocab_size, num_hiddens, ffn_num_hiddens,\n",
#    1142     "                                   num_heads, num_blks, dropout,\n",
#    1143     "                                   max_len=max_len)\n",
#    1144     "        self.hidden = nn.Sequential(nn.LazyLinear(num_hiddens),\n",
#    1145     "                                    nn.Tanh())\n",
#    1146     "        self.mlm = MaskLM(vocab_size, num_hiddens)\n",
#    1147     "        self.nsp = NextSentencePred()\n",
#    1148     "\n",
#    1149     "    def forward(self, tokens, segments, valid_lens=None, pred_positions=None):\n",
#    1150     "        encoded_X = self.encoder(tokens, segments, valid_lens)\n",
#    1151     "        if pred_positions is not None:\n",
#    1152     "            mlm_Y_hat = self.mlm(encoded_X, pred_positions)\n",
#    1153     "        else:\n",
#    1154     "            mlm_Y_hat = None\n",
#    1155     "        # The hidden layer of the MLP classifier for next sentence prediction.\n",
#    1156     "        # 0 is the index of the '<cls>' token\n",
#    1157     "        nsp_Y_hat = self.nsp(self.hidden(encoded_X[:, 0, :]))\n",
#    1158     "        return encoded_X, mlm_Y_hat, nsp_Y_hat\n"
#    1159    ]
#    1160   },
#    1161   {
#    1162    "cell_type": "code",
#    1163    "execution_count": 37,
#    1164    "id": "ad6de746-239d-41ca-bcd4-9d22fd8a9ed1",
#    1165    "metadata": {},
#    1166    "outputs": [],
#    1167    "source": [
#    1168     "class SNLIBERTDataset(torch.utils.data.Dataset):\n",
#    1169     "    def __init__(self, dataset, max_len, vocab=None):\n",
#    1170     "        all_premise_hypothesis_tokens = [[p_tokens, h_tokens] for p_tokens, h_tokens in zip(*[tokenize([s.lower() for s in sentences]) for sentences in dataset[:2]])]\n",
#    1171     "        self.labels = torch.tensor(dataset[2])\n",
#    1172     "        self.vocab = vocab\n",
#    1173     "        self.max_len = max_len\n",
#    1174     "        (self.all_token_ids, self.all_segments,\n",
#    1175     "        self.valid_lens) = self._preprocess(all_premise_hypothesis_tokens)\n",
#    1176     "        print(' ---> read ' + str(len(self.all_token_ids)) + ' examples')\n",
#    1177     "    def _preprocess(self, all_premise_hypothesis_tokens):\n",
#    1178     "        pool = multiprocessing.Pool(4) # Use 4 worker processes\n",
#    1179     "        out = pool.map(self._mp_worker, all_premise_hypothesis_tokens)\n",
#    1180     "        all_token_ids = [token_ids for token_ids, segments, valid_len in out]\n",
#    1181     "        all_segments = [segments for token_ids, segments, valid_len in out]\n",
#    1182     "        valid_lens = [valid_len for token_ids, segments, valid_len in out]\n",
#    1183     "        return (torch.tensor(all_token_ids, dtype=torch.long), torch.tensor(all_segments, dtype=torch.long), torch.tensor(valid_lens))\n",
#    1184     "    def _mp_worker(self, premise_hypothesis_tokens):\n",
#    1185     "        p_tokens, h_tokens = premise_hypothesis_tokens\n",
#    1186     "        self._truncate_pair_of_tokens(p_tokens, h_tokens)\n",
#    1187     "        tokens, segments = get_tokens_and_segments(p_tokens, h_tokens)\n",
#    1188     "        token_ids = self.vocab[tokens] + [self.vocab['<pad>']] \\\n",
#    1189     "        * (self.max_len - len(tokens))\n",
#    1190     "        segments = segments + [0] * (self.max_len - len(segments))\n",
#    1191     "        valid_len = len(tokens)\n",
#    1192     "        return token_ids, segments, valid_len\n",
#    1193     "    def _truncate_pair_of_tokens(self, p_tokens, h_tokens):\n",
#    1194     "        # Reserve slots for '<CLS>', '<SEP>', and '<SEP>' tokens for the BERT\n",
#    1195     "        # input\n",
#    1196     "        while len(p_tokens) + len(h_tokens) > self.max_len - 3:\n",
#    1197     "            if len(p_tokens) > len(h_tokens):\n",
#    1198     "                p_tokens.pop()\n",
#    1199     "            else:\n",
#    1200     "                h_tokens.pop()\n",
#    1201     "    def __getitem__(self, idx):\n",
#    1202     "        return (self.all_token_ids[idx], self.all_segments[idx], self.valid_lens[idx]), self.labels[idx]\n",
#    1203     "    def __len__(self):\n",
#    1204     "        return len(self.all_token_ids)\n"
#    1205    ]
#    1206   },
#    1207   {
#    1208    "cell_type": "code",
#    1209    "execution_count": 38,
#    1210    "id": "762df892-c06d-42f4-97b4-2965981fa2bf",
#    1211    "metadata": {},
#    1212    "outputs": [],
#    1213    "source": [
#    1214     "class BERTClassifier(nn.Module):\n",
#    1215     "    def __init__(self, bert):\n",
#    1216     "        super(BERTClassifier, self).__init__()\n",
#    1217     "        self.encoder = bert.encoder\n",
#    1218     "        self.hidden = bert.hidden\n",
#    1219     "        self.output = nn.LazyLinear(3)\n",
#    1220     "    def forward(self, inputs):\n",
#    1221     "        tokens_X, segments_X, valid_lens_x = inputs\n",
#    1222     "        encoded_X = self.encoder(tokens_X, segments_X, valid_lens_x)\n",
#    1223     "        return self.output(self.hidden(encoded_X[:, 0, :]))"
#    1224    ]
#    1225   },
#    1226   {
#    1227    "cell_type": "code",
#    1228    "execution_count": 39,
#    1229    "id": "61b11681-4ff2-4237-996c-096e3ea9ca0a",
#    1230    "metadata": {},
#    1231    "outputs": [],
#    1232    "source": [
#    1233     "class BERT(nn.Module):\n",
#    1234     "    \"\"\" Utility class for BERT based embeddings processing, training, testing. \"\"\"\n",
#    1235     "    def __init__(self):\n",
#    1236     "        super(BERT, self).__init__()\n",
#    1237     "    def load_pretrained_model(self, pretrained_model, num_hiddens, ffn_num_hiddens, num_heads, num_blks, dropout, max_len, devices):\n",
#    1238     "        data_dir = download_extract(pretrained_model)\n",
#    1239     "        # Define an empty vocabulary to load the predefined vocabulary\n",
#    1240     "        vocab = Vocab()\n",
#    1241     "        vocab.idx_to_token = json.load(open(os.path.join(data_dir, 'vocab.json')))\n",
#    1242     "        vocab.token_to_idx = {token: idx for idx, token in enumerate(\n",
#    1243     "        vocab.idx_to_token)}\n",
#    1244     "        bert = BERTModel(len(vocab), num_hiddens, ffn_num_hiddens=ffn_num_hiddens, num_heads=num_heads,num_blks=num_blks, dropout=dropout, max_len=max_len)\n",
#    1245     "        # Load pretrained BERT parameters\n",
#    1246     "        bert.load_state_dict(torch.load(os.path.join(data_dir, 'pretrained.params')))\n",
#    1247     "        return bert, vocab\n",
#    1248     "    def get_dataset_iter(self, data_dir, is_training_data, max_len, batch_size, vocab):\n",
#    1249     "        num_workers = get_dataloader_workers()\n",
#    1250     "        data_set = SNLIBERTDataset(read_snli(data_dir, is_training_data), max_len, vocab)\n",
#    1251     "        data_set_iter = torch.utils.data.DataLoader(data_set, batch_size, shuffle=is_training_data, num_workers=num_workers)\n",
#    1252     "        return data_set_iter\n",
#    1253     "    def predict(self, net, vocab, premise, hypothesis):\n",
#    1254     "        \"\"\"Predict the logical relationship between the premise and hypothesis.\"\"\"\n",
#    1255     "        # Set the model to evaluation mode\n",
#    1256     "        net.eval()\n",
#    1257     "        device = next(iter(net.parameters())).device\n",
#    1258     "        premise_tokens =  [elem.split('.')[0] if '.' in elem else elem for elem in premise.rstrip().split(' ')] + ['.']\n",
#    1259     "        hypothesis_tokens =  [elem.split('.')[0] if '.' in elem else elem for elem in hypothesis.rstrip().split(' ')] + ['.']\n",
#    1260     "        tokens, segments = get_tokens_and_segments(premise_tokens, hypothesis_tokens)\n",
#    1261     "        token_ids = torch.tensor(vocab[tokens], device=device).unsqueeze(0)\n",
#    1262     "        segments = torch.tensor(segments, device=device).unsqueeze(0)\n",
#    1263     "        valid_len = torch.tensor(len(tokens), device=device).unsqueeze(0)\n",
#    1264     "        label = torch.argmax(net((token_ids,segments,valid_len)), dim=1)\n",
#    1265     "        return 'entailment' if label == 0 else 'contradiction' if label == 1 else 'neutral'"
#    1266    ]
#    1267   },
#    1268   {
#    1269    "cell_type": "code",
#    1270    "execution_count": 40,
#    1271    "id": "7471c275-8794-4f61-917b-b49e3f2839df",
#    1272    "metadata": {},
#    1273    "outputs": [],
#    1274    "source": [
#    1275     "def format_data(data, mode=None):\n",
#    1276     "    if mode:\n",
#    1277     "        _mode = data[mode]\n",
#    1278     "        return [_mode['total_examples'], _mode['passed'], _mode['failed'], _mode['accuracy'], _mode['loss']]\n",
#    1279     "    else:\n",
#    1280     "        training = data['training']\n",
#    1281     "        test = data['test']\n",
#    1282     "        return [ [\"Training\", training['total_examples'], training['passed'], training['failed'], training['accuracy'], training['loss'] ],\n",
#    1283     "                 [\"Test\", test['total_examples'], test['passed'], test['failed'], test['accuracy'], test['loss']] ]"
#    1284    ]
#    1285   },
#    1286   {
#    1287    "cell_type": "code",
#    1288    "execution_count": 41,
#    1289    "id": "e95ff1e9-46a6-4e8c-9cc2-6ec9ca65d49f",
#    1290    "metadata": {},
#    1291    "outputs": [],
#    1292    "source": [
#    1293     "def format_kb(x, pos):\n",
#    1294     "    \"\"\"Formats the y-axis values to K.\"\"\"\n",
#    1295     "    return f'{x // 1000} K'\n",
#    1296     "    \n",
#    1297     "def display_results(data, title):\n",
#    1298     "    tabular_data = format_data(data)\n",
#    1299     "    training_data = format_data(data, 'training')\n",
#    1300     "    test_data = format_data(data, 'test')\n",
#    1301     "    columns = [\"Mode\", \"Total examples\", \"Passed\", \"Failed\", \"Accuracy\", \"Loss\"]\n",
#    1302     "    modes = [\"Training\", \"Test\"]\n",
#    1303     "    subgroups = [\"Passed\", \"Failed\"]\n",
#    1304     "    df = pd.DataFrame(tabular_data, columns=columns)\n",
#    1305     "\n",
#    1306     "    fig = plt.figure(figsize=(8.5,5))\n",
#    1307     "\n",
#    1308     "    for i in range(1):\n",
#    1309     "        ax = plt.subplot2grid((2,2), (0,2*i), colspan=2)\n",
#    1310     "        # Hide axes\n",
#    1311     "        fig.patch.set_visible(False)\n",
#    1312     "        ax.axis('off')\n",
#    1313     "        ax.axis('tight')\n",
#    1314     "        ax.table(cellText=df.values, colLabels=df.columns, loc='center', cellLoc='center')\n",
#    1315     "        ax.set_title(title)\n",
#    1316     "    row2 = 5\n",
#    1317     "    # Define bar width and positions\n",
#    1318     "    bar_width = .20\n",
#    1319     "    x_positions = np.arange(1)\n",
#    1320     "    normalized_training_data = [training_data[1], training_data[2]]\n",
#    1321     "    normalized_test_data = [test_data[1], test_data[2]]\n",
#    1322     "    for j in range(row2-1):\n",
#    1323     "        ax = plt.subplot2grid((2,2*row2), (1,2*j+1), colspan=2)\n",
#    1324     "        if j == 0:\n",
#    1325     "            for i, subgroup in enumerate(subgroups):\n",
#    1326     "                ax.bar(x_positions + i * bar_width, normalized_training_data[i],bar_width, label=subgroup)\n",
#    1327     "            ax.set_xticks(x_positions + bar_width / 2)\n",
#    1328     "            ax.set_xticklabels([\"Training\"])\n",
#    1329     "            ax.yaxis.set_major_formatter(tkr.FuncFormatter(format_kb))\n",
#    1330     "        elif j == 1:\n",
#    1331     "            for i, subgroup in enumerate(subgroups):\n",
#    1332     "                ax.bar(x_positions + i * bar_width, normalized_test_data[i],bar_width, label=subgroup)\n",
#    1333     "            # Customize the plot\n",
#    1334     "            ax.set_xticks(x_positions + bar_width / 2)\n",
#    1335     "            ax.set_xticklabels([\"Test\"])\n",
#    1336     "            ax.yaxis.set_major_formatter(tkr.FuncFormatter(format_kb))\n",
#    1337     "        elif j == 2:\n",
#    1338     "            ax.pie([training_data[1], training_data[2]], labels=[\"passed\", \"failed\"], autopct='%1.1f%%', startangle=90)\n",
#    1339     "            ax.set_title('Training')\n",
#    1340     "        else:\n",
#    1341     "            ax.pie([test_data[1], test_data[2]], labels=[\"passed\", \"failed\"], autopct='%1.1f%%', startangle=90)\n",
#    1342     "            ax.set_title('Test') \n",
#    1343     "        \n",
#    1344     "    # Adjust layout to prevent overlapping titles\n",
#    1345     "    plt.tight_layout()\n",
#    1346     "    plt.savefig(f\"images/{title}.png\")\n",
#    1347     "    plt.show()\n",
#    1348     "    plt.close()\n"
#    1349    ]
#    1350   },
#    1351   {
#    1352    "cell_type": "code",
#    1353    "execution_count": null,
#    1354    "id": "bf9edffc-c243-4b36-acb3-5eb8256a412f",
#    1355    "metadata": {},
#    1356    "outputs": [],
#    1357    "source": []
#    1358   }
#    1359  ],
#    1360  "metadata": {
#    1361   "kernelspec": {
#    1362    "display_name": "Python 3 (ipykernel)",
#    1363    "language": "python",
#    1364    "name": "python3"
#    1365   },
#    1366   "language_info": {
#    1367    "codemirror_mode": {
#    1368     "name": "ipython",
#    1369     "version": 3
#    1370    },
#    1371    "file_extension": ".py",
#    1372    "mimetype": "text/x-python",
#    1373    "name": "python",
#    1374    "nbconvert_exporter": "python",
#    1375    "pygments_lexer": "ipython3",
#    1376    "version": "3.9.21"
#    1377   }
#    1378  },
#    1379  "nbformat": 4,
#    1380  "nbformat_minor": 5
#    1381 }
#
# RuntimeError: MPS backend out of memory (MPS allocated: 43.88 GB, other allocations: 1.73 GB, max allowed: 45.90 GB). Tried to allocate 384.00 MB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).

# %%
# Out:
# None

# %%
# display results
display_results(results, "BERT.Embeddings")
